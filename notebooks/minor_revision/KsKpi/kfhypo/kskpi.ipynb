# %%
from run_kinfit import run_kinfit, build_custom_hypo
from draw_funcs import draw_1d_hist, draw_1d_hists, vertices_plot2, draw_2d_hist, draw_scatter
from ROOT import TFile
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.26/08

# %%
build_custom_hypo('Hypo2PiVertex.cpp')
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/Hypo2PiVertex_cpp.so

# %%
input_path = "/var/kinfit/data/tr_ph_run049912.root"
output_path = "kinfit_kskpi_run049912.root"

# %%
run_kinfit(input_path, output_path=output_path, mfield=1.0)
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# (TFile &) Name: /var/kinfit/data/tr_ph_run049912.root Title:
# (TrPh &) @0x7f19be01c000
#  [STATUS : 01%]	CPU TIME: 23.550	REAL TIME: 23.527
#  [STATUS : 02%]	CPU TIME: 21.050	REAL TIME: 21.041
#  [STATUS : 03%]	CPU TIME: 22.870	REAL TIME: 22.869
#  [STATUS : 04%]	CPU TIME: 18.900	REAL TIME: 18.878
#  [STATUS : 05%]	CPU TIME: 20.520	REAL TIME: 20.524
#  [STATUS : 06%]	CPU TIME: 21.440	REAL TIME: 21.420
#  [STATUS : 07%]	CPU TIME: 18.630	REAL TIME: 18.613
#  [STATUS : 08%]	CPU TIME: 20.680	REAL TIME: 20.678
#  [STATUS : 09%]	CPU TIME: 17.820	REAL TIME: 17.809
#  [STATUS : 10%]	CPU TIME: 21.740	REAL TIME: 21.709
#  [STATUS : 11%]	CPU TIME: 21.310	REAL TIME: 21.280
#  [STATUS : 12%]	CPU TIME: 21.240	REAL TIME: 21.239
#  [STATUS : 13%]	CPU TIME: 20.620	REAL TIME: 20.596
#  [STATUS : 14%]	CPU TIME: 20.510	REAL TIME: 20.498
#  [STATUS : 15%]	CPU TIME: 20.380	REAL TIME: 20.371
#  [STATUS : 16%]	CPU TIME: 19.680	REAL TIME: 19.663
#  [STATUS : 17%]	CPU TIME: 20.680	REAL TIME: 20.691
#  [STATUS : 18%]	CPU TIME: 20.930	REAL TIME: 20.899
#  [STATUS : 19%]	CPU TIME: 21.320	REAL TIME: 21.315
#  [STATUS : 20%]	CPU TIME: 17.840	REAL TIME: 17.819
#  [STATUS : 21%]	CPU TIME: 20.980	REAL TIME: 20.964
#  [STATUS : 22%]	CPU TIME: 18.660	REAL TIME: 18.650
#  [STATUS : 23%]	CPU TIME: 18.270	REAL TIME: 18.255
#  [STATUS : 24%]	CPU TIME: 18.280	REAL TIME: 18.275
#  [STATUS : 25%]	CPU TIME: 19.110	REAL TIME: 19.088
#  [STATUS : 26%]	CPU TIME: 19.270	REAL TIME: 19.245
#  [STATUS : 27%]	CPU TIME: 20.000	REAL TIME: 19.988
#  [STATUS : 28%]	CPU TIME: 18.530	REAL TIME: 18.511
#  [STATUS : 29%]	CPU TIME: 19.810	REAL TIME: 19.780
#  [STATUS : 30%]	CPU TIME: 21.230	REAL TIME: 21.221
#  [STATUS : 31%]	CPU TIME: 21.200	REAL TIME: 21.173
#  [STATUS : 32%]	CPU TIME: 18.260	REAL TIME: 18.245
#  [STATUS : 33%]	CPU TIME: 20.690	REAL TIME: 20.663
#  [STATUS : 34%]	CPU TIME: 21.680	REAL TIME: 21.661
#  [STATUS : 35%]	CPU TIME: 21.640	REAL TIME: 21.627
#  [STATUS : 36%]	CPU TIME: 20.080	REAL TIME: 20.048
#  [STATUS : 37%]	CPU TIME: 20.940	REAL TIME: 20.921
#  [STATUS : 38%]	CPU TIME: 17.860	REAL TIME: 17.836
#  [STATUS : 39%]	CPU TIME: 20.740	REAL TIME: 20.727
#  [STATUS : 40%]	CPU TIME: 18.130	REAL TIME: 18.105
#  [STATUS : 41%]	CPU TIME: 19.180	REAL TIME: 19.157
#  [STATUS : 42%]	CPU TIME: 20.810	REAL TIME: 20.795
#  [STATUS : 43%]	CPU TIME: 20.750	REAL TIME: 20.730
#  [STATUS : 44%]	CPU TIME: 18.940	REAL TIME: 18.920
#  [STATUS : 45%]	CPU TIME: 19.610	REAL TIME: 19.591
#  [STATUS : 46%]	CPU TIME: 20.280	REAL TIME: 20.261
#  [STATUS : 47%]	CPU TIME: 19.480	REAL TIME: 19.472
#  [STATUS : 48%]	CPU TIME: 19.710	REAL TIME: 19.682
#  [STATUS : 49%]	CPU TIME: 21.570	REAL TIME: 21.545
#  [STATUS : 50%]	CPU TIME: 20.420	REAL TIME: 20.398
#  [STATUS : 51%]	CPU TIME: 20.860	REAL TIME: 20.830
#  [STATUS : 52%]	CPU TIME: 19.180	REAL TIME: 19.170
#  [STATUS : 53%]	CPU TIME: 18.500	REAL TIME: 18.476
#  [STATUS : 54%]	CPU TIME: 18.360	REAL TIME: 18.348
#  [STATUS : 55%]	CPU TIME: 19.790	REAL TIME: 19.770
#  [STATUS : 56%]	CPU TIME: 19.520	REAL TIME: 19.493
#  [STATUS : 57%]	CPU TIME: 17.600	REAL TIME: 17.579
#  [STATUS : 58%]	CPU TIME: 19.330	REAL TIME: 19.317
#  [STATUS : 59%]	CPU TIME: 20.920	REAL TIME: 20.894
#  [STATUS : 60%]	CPU TIME: 18.540	REAL TIME: 18.525
#  [STATUS : 61%]	CPU TIME: 18.940	REAL TIME: 18.925
#  [STATUS : 62%]	CPU TIME: 19.540	REAL TIME: 19.507
#  [STATUS : 63%]	CPU TIME: 19.970	REAL TIME: 19.943
#  [STATUS : 64%]	CPU TIME: 19.460	REAL TIME: 19.431
#  [STATUS : 65%]	CPU TIME: 17.470	REAL TIME: 17.453
#  [STATUS : 66%]	CPU TIME: 20.960	REAL TIME: 20.947
#  [STATUS : 67%]	CPU TIME: 19.550	REAL TIME: 19.529
#  [STATUS : 68%]	CPU TIME: 22.080	REAL TIME: 22.049
#  [STATUS : 69%]	CPU TIME: 20.110	REAL TIME: 20.095
#  [STATUS : 70%]	CPU TIME: 17.040	REAL TIME: 17.017
#  [STATUS : 71%]	CPU TIME: 19.340	REAL TIME: 19.321
#  [STATUS : 72%]	CPU TIME: 20.170	REAL TIME: 20.164
#  [STATUS : 73%]	CPU TIME: 21.440	REAL TIME: 21.411
#  [STATUS : 74%]	CPU TIME: 18.460	REAL TIME: 18.460
#  [STATUS : 75%]	CPU TIME: 19.890	REAL TIME: 19.861
#  [STATUS : 76%]	CPU TIME: 18.460	REAL TIME: 18.475
#  [STATUS : 77%]	CPU TIME: 21.320	REAL TIME: 21.297
#  [STATUS : 78%]	CPU TIME: 18.830	REAL TIME: 18.811
#  [STATUS : 79%]	CPU TIME: 18.060	REAL TIME: 18.046
#  [STATUS : 80%]	CPU TIME: 20.020	REAL TIME: 20.002
#  [STATUS : 81%]	CPU TIME: 19.450	REAL TIME: 19.435
#  [STATUS : 82%]	CPU TIME: 20.410	REAL TIME: 20.390
#  [STATUS : 83%]	CPU TIME: 18.590	REAL TIME: 18.560
#  [STATUS : 84%]	CPU TIME: 22.310	REAL TIME: 22.304
#  [STATUS : 85%]	CPU TIME: 19.870	REAL TIME: 19.845
#  [STATUS : 86%]	CPU TIME: 17.570	REAL TIME: 17.547
#  [STATUS : 87%]	CPU TIME: 20.630	REAL TIME: 20.610
#  [STATUS : 88%]	CPU TIME: 17.680	REAL TIME: 17.648
#  [STATUS : 89%]	CPU TIME: 21.940	REAL TIME: 21.909
#  [STATUS : 90%]	CPU TIME: 17.970	REAL TIME: 17.958
#  [STATUS : 91%]	CPU TIME: 20.010	REAL TIME: 19.988
#  [STATUS : 92%]	CPU TIME: 18.330	REAL TIME: 18.303
#  [STATUS : 93%]	CPU TIME: 18.100	REAL TIME: 18.073
#  [STATUS : 94%]	CPU TIME: 18.190	REAL TIME: 18.175
#  [STATUS : 95%]	CPU TIME: 19.300	REAL TIME: 19.275
#  [STATUS : 96%]	CPU TIME: 20.950	REAL TIME: 20.920
#  [STATUS : 97%]	CPU TIME: 22.900	REAL TIME: 22.896
#  [STATUS : 98%]	CPU TIME: 17.470	REAL TIME: 17.487
#  [STATUS : 99%]	CPU TIME: 19.190	REAL TIME: 19.154
# _________________________________________
# TOTAL NUMBER OF EVENTS BEFORE CUTS:	100000
# NUBER OF EVENTS TO THE INPUT OF KINFIT:	21660
# NUMBER OF EVENTS PASSED e+e- --> KsK+pi- HYPO:	10482
# NUMBER OF EVENTS PASSED e+e- --> KsK-pi+ HYPO:	10685
# NUMBER OF EVENTS PASSED e+e- --> KsK+-pi-+ HYPOS:	21167
# TOTAL CPU TIME :	1981.520
# TOTAL REAL TIME :	1979.706
# _________________________________________
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh_C.so
# In file included from /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh_C_ACLiC_dict.cxx:41:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C: In member function ‘virtual void TrPh::Loop(const std::string&, double)’:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:282:10: warning: ‘v_sigma_z_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   282 |   double v_sigma_z_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:281:10: warning: ‘v_sigma_y_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   281 |   double v_sigma_y_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:280:10: warning: ‘v_sigma_x_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   280 |   double v_sigma_x_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:279:10: warning: ‘v_sigma_z_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   279 |   double v_sigma_z_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:278:10: warning: ‘v_sigma_y_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   278 |   double v_sigma_y_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:277:10: warning: ‘v_sigma_x_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   277 |   double v_sigma_x_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:275:10: warning: ‘v_sigma_z_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   275 |   double v_sigma_z_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:274:10: warning: ‘v_sigma_y_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   274 |   double v_sigma_y_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:273:10: warning: ‘v_sigma_x_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   273 |   double v_sigma_x_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:272:10: warning: ‘v_sigma_z_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   272 |   double v_sigma_z_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:271:10: warning: ‘v_sigma_y_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   271 |   double v_sigma_y_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:270:10: warning: ‘v_sigma_x_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   270 |   double v_sigma_x_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# In file included from /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh_C_ACLiC_dict.cxx:41:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C: In member function ‘virtual void TrPh::Loop(const std::string&, double)’:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:282:10: warning: ‘v_sigma_z_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   282 |   double v_sigma_z_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:281:10: warning: ‘v_sigma_y_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   281 |   double v_sigma_y_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:280:10: warning: ‘v_sigma_x_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   280 |   double v_sigma_x_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:279:10: warning: ‘v_sigma_z_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   279 |   double v_sigma_z_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:278:10: warning: ‘v_sigma_y_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   278 |   double v_sigma_y_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:277:10: warning: ‘v_sigma_x_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   277 |   double v_sigma_x_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:275:10: warning: ‘v_sigma_z_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   275 |   double v_sigma_z_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:274:10: warning: ‘v_sigma_y_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   274 |   double v_sigma_y_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:273:10: warning: ‘v_sigma_x_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   273 |   double v_sigma_x_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:272:10: warning: ‘v_sigma_z_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   272 |   double v_sigma_z_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:271:10: warning: ‘v_sigma_y_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   271 |   double v_sigma_y_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/kfhypo/TrPh.C:270:10: warning: ‘v_sigma_x_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   270 |   double v_sigma_x_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~

# %%
fl = TFile.Open(output_path, 'read')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "kf_err==0", "goff")
draw_1d_hist("kf_err_kskpi", xlabel='error code', 
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=5000, h_x=1)
plt.savefig('kf_err_xkpi.eps')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "kf_err==0 && numiters<7", "goff")
draw_1d_hist("kf_err_kskpi", xlabel='error code', 
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=5000, h_x=1)

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(64,0,200)", "kf_err==0 && numiters>6", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
             fraction=0.47,
             info_coords=(0.0, -1.0),
            h_y=200, h_x=50)

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(128,0,200)", "kf_err==0", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
             fraction=0.47,
             info_coords=(0.0, -1.0),
            h_y=200, h_x=50)
plt.savefig('kf_chi2_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("in_mks>>in_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(512,0.4,0.6)", "kf_err==0", "goff")
draw_1d_hists([('kf_vtx_mks', 'vertex fit'), ('kf_mks', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
              fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=200, h_x=0.05)
plt.savefig('kf_mks_xkpi.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fl.kf_data.Draw("kf_vtx0[0]>>kf_vtx0_x(128, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx0[1]>>kf_vtx0_y(128, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx0[2]>>kf_vtx0_z(128, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[0]>>kf_vtx1_x(128, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[1]>>kf_vtx1_y(128, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[2]>>kf_vtx1_z(128, -10, 10)", "kf_err==0", "goff")
vertices_plot2([['kf_vtx0_x', 'kf_vtx1_x'], 
               ['kf_vtx0_y', 'kf_vtx1_y'],
               ['kf_vtx0_z', 'kf_vtx1_z']],
               fraction=0.8, 
               hspace=0.4, 
               wspace=0.6,
              hs_y=[[6000, 800], [6000, 800], [150, 150]],
              hs_x=[[5, 5], [5, 5], [5, 5]])
plt.savefig('kf_vtx_xkpi.eps')

# %%
fl.kf_data.Draw("kf_vtx0[2]-sim_ee_vtx[2]>>kf_vtx_dz1(128, -5, 5)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dz1", 
             xlabel=r'$\Delta z_{1}$ (cm)',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
           h_y=500, h_x=2.5)
plt.savefig('kf_vtx_dz1_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx1[0]-sim_ks_vtx[0] >>kf_vtx_dx2(128, -0.5, 0.5)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dx2", 
             xlabel=r'$\Delta x_{2}$ (cm)',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=500, h_x=0.25)
plt.savefig('kf_vtx_dx2_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx1[1]-sim_ks_vtx[1]>>kf_vtx_dy2(128, -0.5, 0.5)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dy2", 
             xlabel=r'$\Delta y_{2}$ (cm)',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=500, h_x=0.25)
plt.savefig('kf_vtx_dy2_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx1[2]-sim_ks_vtx[2]>>kf_vtx_dz2(128, -5., 5.)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dz2", 
             xlabel=r'$\Delta z_{2}$ (cm)',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=500, h_x=2.5)
plt.savefig('kf_vtx_dz2_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx_dr>>kf_vtx_dr(128, 0, 15)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dr", 
             xlabel=r'$\Delta r_{\text{fit}}$ (cm)',
             ylabel='events',
             fraction=0.47, 
            info_coords=(0.3, 0.3),
            h_y=300, h_x=5)
plt.savefig('kf_vtx_dr_xkpi.eps')

# %%
fl.kf_data.Draw("kf_ks_decay_prod_angle>>kf_angle(32, 0, 3.14159)", "kf_err==0", "goff")
draw_1d_hist("kf_angle", xlabel=r'$\alpha$ (rad)')
plt.savefig('kf_ks_prod_angle_xkpi.eps')

# %%
fl.kf_data.Draw("kf_vtx_drho>>kf_vtx_drho(128, 0, 15)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_drho", xlabel=r'$\Delta\rho$ (cm)')
plt.savefig('kf_vtx_drho_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_K:kf_p_vtx0_K>>pdedx_K(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_K', xlabel=r'$P$ (GeV/c)', ylabel=r'$dE/dx\text{ (AU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_K_from_vtx0_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_pi:kf_p_vtx0_pi>>pdedx_vtx0_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx0_pi', xlabel=r'$P$ (GeV/c)', ylabel=r'$dE/dx\text{ (AU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx0_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx1_pi[0]:kf_p_vtx1_pi[0]>>pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_dedx_vtx1_pi[1]:kf_p_vtx1_pi[1]>>+pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx1_pi', xlabel=r'$P$ (GeV/c)', ylabel=r'$dE/dx\text{ (AU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx1_xkpi.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', 
             xlabel=r'$\Delta r_{\text{sim}}$ (cm)', 
             ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)', 
             fraction=0.47)
plt.savefig('kf_sim_vs_kf_dr_xkpi.eps')

# %%
fl.kf_data.Draw("sim_vtx_dr:kf_vtx_dr>>sim_kf_vtx_dr(64, 0, 15., 64, 0, 15.)", "kf_err==0", "goff")
draw_2d_hist('sim_kf_vtx_dr', 
            xlabel=r'$\Delta r_{\text{sim}}$ (cm)', 
            ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)',
            fraction=0.47)
plt.savefig('kf_sim_vs_kf_dr_colormap_xkpi.eps')

# %%
fl.kf_data.Draw("(kf_vtx_dr-sim_vtx_dr)>>kf_delta_dr(512, -2, 2)", "kf_err==0", "goff")
draw_1d_hist("kf_delta_dr", 
             xlabel=r'$\Delta r_{\text{fit}}-\Delta r_{\text{sim}}$ (cm)',
             ylabel='events',
            fraction=0.8,
            info_coords=(0.55, 0.5),
            h_y=300, h_x=1)
plt.savefig('kf_sim_vs_kf_dr_1d_xkpi.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0 && kf_chi2<100", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', 
             xlabel=r'$\Delta r_{\text{sim}}$ (cm)', 
             ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)',
            fraction=0.47)
plt.savefig('kf_sim_vs_kf_dr_chi2_100_xkpi.eps')

# %%
fl.kf_data.Draw("sim_vtx_dr:kf_vtx_dr>>sim_kf_vtx_dr_100(64, 0, 15., 64, 0, 15.)", 
                "kf_err==0 && kf_chi2<100", "goff")
draw_2d_hist('sim_kf_vtx_dr_100', 
            xlabel=r'$\Delta r_{\text{sim}}$ (cm)', 
            ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)',
            fraction=0.47)
plt.savefig('kf_sim_vs_kf_dr_chi2_100_colormap_xkpi.eps')

# %%
fl.kf_data.Draw("(kf_vtx_dr-sim_vtx_dr)>>kf_delta_dr_100(256, -5, 5)", 
                "kf_err==0 && kf_chi2<100", "goff")
draw_1d_hist("kf_delta_dr_100", xlabel=r'$\Delta r$ (cm)',
            fraction=0.47)
plt.savefig('kf_sim_vs_kf_dr_chi2_100_1d_xkpi.eps')

# %%
fl.kf_data.Draw("kf_hypo>>kf_hypo_sim0", 
                "kf_err==0 && sim_hypo==0", "goff")
draw_1d_hist("kf_hypo_sim0", xlabel=r'',
            fraction=0.47)
plt.savefig('kf_hypo_kskplpimi_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_hypo>>kf_hypo_sim1", 
                "kf_err==0 && sim_hypo==1", "goff")
draw_1d_hist("kf_hypo_sim1", xlabel=r'',
            fraction=0.47)
plt.savefig('kf_hypo_kskmipipl_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks(128,0.4,0.6)", "kf_err==0 && kf_hypo==1 && sim_hypo==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>+kf_vtx_mks", "kf_err==0 && kf_hypo==0 && sim_hypo==1", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(128,0.4,0.6)", "kf_err==0 && kf_hypo==1 && sim_hypo==0", "goff")
fl.kf_data.Draw("kf_mks>>+kf_mks", "kf_err==0 && kf_hypo==0 && sim_hypo==1", "goff")
draw_1d_hists([('kf_vtx_mks', 'vertex fit'), ('kf_mks', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=100, h_x=0.05)
plt.savefig('kf_mks_wrong_xkpi.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks1(128,0.4,0.6)", "kf_err==0 && kf_hypo==0 && sim_hypo==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>+kf_vtx_mks1", "kf_err==0 && kf_hypo==1 && sim_hypo==1", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks1(128,0.4,0.6)", "kf_err==0 && kf_hypo==0 && sim_hypo==0", "goff")
fl.kf_data.Draw("kf_mks>>+kf_mks1", "kf_err==0 && kf_hypo==1 && sim_hypo==1", "goff")
draw_1d_hists([('kf_vtx_mks1', 'vertex fit'), ('kf_mks1', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=500, h_x=0.05)
plt.savefig('kf_mks_good_xkpi.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# fl.Close()
