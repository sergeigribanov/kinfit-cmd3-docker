# %%
from run_kinfit import run_kinfit, build_custom_hypo
from draw_funcs import draw_1d_hist, draw_1d_hists, vertices_plot2, draw_2d_hist, draw_scatter
from ROOT import TFile, TCanvas
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.26/08

# %%
build_custom_hypo('Hypo2PiVertex.cpp')
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/Hypo2PiVertex_cpp.so

# %%
input_path = "/var/kinfit/data/tr_ph_run049912.root"
output_path = "kinfit_kskpi_run049912.root"

# %%
run_kinfit(input_path, output_path=output_path, mfield=1.0)
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# (TFile &) Name: /var/kinfit/data/tr_ph_run049912.root Title:
# (TrPh &) @0x7f28df0ff000
#  [STATUS : 01%]	CPU TIME: 23.020	REAL TIME: 22.992
#  [STATUS : 02%]	CPU TIME: 22.120	REAL TIME: 22.111
#  [STATUS : 03%]	CPU TIME: 22.230	REAL TIME: 22.218
#  [STATUS : 04%]	CPU TIME: 18.630	REAL TIME: 18.615
#  [STATUS : 05%]	CPU TIME: 19.430	REAL TIME: 19.431
#  [STATUS : 06%]	CPU TIME: 20.650	REAL TIME: 20.639
#  [STATUS : 07%]	CPU TIME: 19.010	REAL TIME: 18.991
#  [STATUS : 08%]	CPU TIME: 22.700	REAL TIME: 22.691
#  [STATUS : 09%]	CPU TIME: 20.690	REAL TIME: 20.672
#  [STATUS : 10%]	CPU TIME: 22.120	REAL TIME: 22.102
#  [STATUS : 11%]	CPU TIME: 21.160	REAL TIME: 21.143
#  [STATUS : 12%]	CPU TIME: 20.580	REAL TIME: 20.558
#  [STATUS : 13%]	CPU TIME: 20.650	REAL TIME: 20.639
#  [STATUS : 14%]	CPU TIME: 20.100	REAL TIME: 20.073
#  [STATUS : 15%]	CPU TIME: 20.520	REAL TIME: 20.514
#  [STATUS : 16%]	CPU TIME: 19.260	REAL TIME: 19.236
#  [STATUS : 17%]	CPU TIME: 20.870	REAL TIME: 20.848
#  [STATUS : 18%]	CPU TIME: 21.190	REAL TIME: 21.169
#  [STATUS : 19%]	CPU TIME: 23.870	REAL TIME: 23.848
#  [STATUS : 20%]	CPU TIME: 19.930	REAL TIME: 19.919
#  [STATUS : 21%]	CPU TIME: 23.890	REAL TIME: 23.860
#  [STATUS : 22%]	CPU TIME: 20.420	REAL TIME: 20.405
#  [STATUS : 23%]	CPU TIME: 20.920	REAL TIME: 20.898
#  [STATUS : 24%]	CPU TIME: 20.450	REAL TIME: 20.427
#  [STATUS : 25%]	CPU TIME: 20.380	REAL TIME: 20.376
#  [STATUS : 26%]	CPU TIME: 20.340	REAL TIME: 20.317
#  [STATUS : 27%]	CPU TIME: 22.680	REAL TIME: 22.661
#  [STATUS : 28%]	CPU TIME: 20.910	REAL TIME: 20.916
#  [STATUS : 29%]	CPU TIME: 20.010	REAL TIME: 19.980
#  [STATUS : 30%]	CPU TIME: 21.940	REAL TIME: 21.925
#  [STATUS : 31%]	CPU TIME: 21.420	REAL TIME: 21.392
#  [STATUS : 32%]	CPU TIME: 18.590	REAL TIME: 18.714
#  [STATUS : 33%]	CPU TIME: 20.850	REAL TIME: 21.012
#  [STATUS : 34%]	CPU TIME: 21.280	REAL TIME: 21.256
#  [STATUS : 35%]	CPU TIME: 21.210	REAL TIME: 21.190
#  [STATUS : 36%]	CPU TIME: 19.740	REAL TIME: 19.718
#  [STATUS : 37%]	CPU TIME: 20.630	REAL TIME: 20.600
#  [STATUS : 38%]	CPU TIME: 17.600	REAL TIME: 17.573
#  [STATUS : 39%]	CPU TIME: 20.590	REAL TIME: 20.581
#  [STATUS : 40%]	CPU TIME: 18.020	REAL TIME: 18.000
#  [STATUS : 41%]	CPU TIME: 18.330	REAL TIME: 18.299
#  [STATUS : 42%]	CPU TIME: 19.840	REAL TIME: 19.814
#  [STATUS : 43%]	CPU TIME: 20.250	REAL TIME: 20.228
#  [STATUS : 44%]	CPU TIME: 18.150	REAL TIME: 18.129
#  [STATUS : 45%]	CPU TIME: 19.080	REAL TIME: 19.055
#  [STATUS : 46%]	CPU TIME: 19.490	REAL TIME: 19.473
#  [STATUS : 47%]	CPU TIME: 18.710	REAL TIME: 18.685
#  [STATUS : 48%]	CPU TIME: 19.060	REAL TIME: 19.037
#  [STATUS : 49%]	CPU TIME: 20.800	REAL TIME: 20.778
#  [STATUS : 50%]	CPU TIME: 19.630	REAL TIME: 19.604
#  [STATUS : 51%]	CPU TIME: 20.340	REAL TIME: 20.303
#  [STATUS : 52%]	CPU TIME: 19.440	REAL TIME: 19.519
#  [STATUS : 53%]	CPU TIME: 19.570	REAL TIME: 19.588
#  [STATUS : 54%]	CPU TIME: 19.100	REAL TIME: 19.148
#  [STATUS : 55%]	CPU TIME: 21.440	REAL TIME: 21.444
#  [STATUS : 56%]	CPU TIME: 19.340	REAL TIME: 19.332
#  [STATUS : 57%]	CPU TIME: 17.070	REAL TIME: 17.041
#  [STATUS : 58%]	CPU TIME: 18.980	REAL TIME: 18.956
#  [STATUS : 59%]	CPU TIME: 20.250	REAL TIME: 20.235
#  [STATUS : 60%]	CPU TIME: 17.910	REAL TIME: 17.893
#  [STATUS : 61%]	CPU TIME: 18.310	REAL TIME: 18.293
#  [STATUS : 62%]	CPU TIME: 18.830	REAL TIME: 18.805
#  [STATUS : 63%]	CPU TIME: 19.290	REAL TIME: 19.270
#  [STATUS : 64%]	CPU TIME: 19.760	REAL TIME: 19.765
#  [STATUS : 65%]	CPU TIME: 18.360	REAL TIME: 18.375
#  [STATUS : 66%]	CPU TIME: 19.720	REAL TIME: 19.708
#  [STATUS : 67%]	CPU TIME: 18.700	REAL TIME: 18.698
#  [STATUS : 68%]	CPU TIME: 19.350	REAL TIME: 19.411
#  [STATUS : 69%]	CPU TIME: 18.350	REAL TIME: 18.379
#  [STATUS : 70%]	CPU TIME: 16.260	REAL TIME: 16.338
#  [STATUS : 71%]	CPU TIME: 18.830	REAL TIME: 18.870
#  [STATUS : 72%]	CPU TIME: 19.040	REAL TIME: 19.076
#  [STATUS : 73%]	CPU TIME: 20.380	REAL TIME: 20.387
#  [STATUS : 74%]	CPU TIME: 16.500	REAL TIME: 16.475
#  [STATUS : 75%]	CPU TIME: 18.420	REAL TIME: 18.405
#  [STATUS : 76%]	CPU TIME: 18.180	REAL TIME: 18.184
#  [STATUS : 77%]	CPU TIME: 20.790	REAL TIME: 20.791
#  [STATUS : 78%]	CPU TIME: 18.530	REAL TIME: 18.558
#  [STATUS : 79%]	CPU TIME: 18.010	REAL TIME: 18.003
#  [STATUS : 80%]	CPU TIME: 20.300	REAL TIME: 20.282
#  [STATUS : 81%]	CPU TIME: 20.440	REAL TIME: 20.415
#  [STATUS : 82%]	CPU TIME: 22.410	REAL TIME: 22.398
#  [STATUS : 83%]	CPU TIME: 19.950	REAL TIME: 19.932
#  [STATUS : 84%]	CPU TIME: 22.410	REAL TIME: 22.386
#  [STATUS : 85%]	CPU TIME: 19.660	REAL TIME: 19.633
#  [STATUS : 86%]	CPU TIME: 17.160	REAL TIME: 17.145
#  [STATUS : 87%]	CPU TIME: 20.890	REAL TIME: 20.896
#  [STATUS : 88%]	CPU TIME: 17.530	REAL TIME: 17.516
#  [STATUS : 89%]	CPU TIME: 21.660	REAL TIME: 21.651
#  [STATUS : 90%]	CPU TIME: 18.040	REAL TIME: 18.020
#  [STATUS : 91%]	CPU TIME: 20.910	REAL TIME: 20.906
#  [STATUS : 92%]	CPU TIME: 18.270	REAL TIME: 18.258
#  [STATUS : 93%]	CPU TIME: 17.810	REAL TIME: 17.782
#  [STATUS : 94%]	CPU TIME: 18.200	REAL TIME: 18.190
#  [STATUS : 95%]	CPU TIME: 19.770	REAL TIME: 19.751
#  [STATUS : 96%]	CPU TIME: 21.150	REAL TIME: 21.128
#  [STATUS : 97%]	CPU TIME: 21.270	REAL TIME: 21.257
#  [STATUS : 98%]	CPU TIME: 16.530	REAL TIME: 16.513
#  [STATUS : 99%]	CPU TIME: 19.490	REAL TIME: 19.476
# _________________________________________
# TOTAL NUMBER OF EVENTS BEFORE CUTS:	100000
# NUBER OF EVENTS TO THE INPUT OF KINFIT:	21660
# NUMBER OF EVENTS PASSED e+e- --> KsK+pi- HYPO:	10420
# NUMBER OF EVENTS PASSED e+e- --> KsK-pi+ HYPO:	10579
# NUMBER OF EVENTS PASSED e+e- --> KsK+-pi-+ HYPOS:	20999
# TOTAL CPU TIME :	1986.450
# TOTAL REAL TIME :	1985.682
# _________________________________________
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh_C.so
# In file included from /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh_C_ACLiC_dict.cxx:41:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C: In member function ‘virtual void TrPh::Loop(const std::string&, double)’:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:289:10: warning: ‘v_sigma_z_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   289 |   double v_sigma_z_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:288:10: warning: ‘v_sigma_y_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   288 |   double v_sigma_y_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:287:10: warning: ‘v_sigma_x_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   287 |   double v_sigma_x_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:286:10: warning: ‘v_sigma_z_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   286 |   double v_sigma_z_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:285:10: warning: ‘v_sigma_y_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   285 |   double v_sigma_y_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:284:10: warning: ‘v_sigma_x_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   284 |   double v_sigma_x_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:282:10: warning: ‘v_sigma_z_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   282 |   double v_sigma_z_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:281:10: warning: ‘v_sigma_y_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   281 |   double v_sigma_y_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:280:10: warning: ‘v_sigma_x_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   280 |   double v_sigma_x_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:279:10: warning: ‘v_sigma_z_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   279 |   double v_sigma_z_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:278:10: warning: ‘v_sigma_y_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   278 |   double v_sigma_y_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:277:10: warning: ‘v_sigma_x_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   277 |   double v_sigma_x_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# In file included from /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh_C_ACLiC_dict.cxx:41:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C: In member function ‘virtual void TrPh::Loop(const std::string&, double)’:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:289:10: warning: ‘v_sigma_z_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   289 |   double v_sigma_z_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:288:10: warning: ‘v_sigma_y_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   288 |   double v_sigma_y_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:287:10: warning: ‘v_sigma_x_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   287 |   double v_sigma_x_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:286:10: warning: ‘v_sigma_z_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   286 |   double v_sigma_z_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:285:10: warning: ‘v_sigma_y_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   285 |   double v_sigma_y_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:284:10: warning: ‘v_sigma_x_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   284 |   double v_sigma_x_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:282:10: warning: ‘v_sigma_z_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   282 |   double v_sigma_z_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:281:10: warning: ‘v_sigma_y_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   281 |   double v_sigma_y_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:280:10: warning: ‘v_sigma_x_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   280 |   double v_sigma_x_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:279:10: warning: ‘v_sigma_z_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   279 |   double v_sigma_z_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:278:10: warning: ‘v_sigma_y_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   278 |   double v_sigma_y_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo/TrPh.C:277:10: warning: ‘v_sigma_x_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   277 |   double v_sigma_x_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~

# %%
fl = TFile.Open(output_path, 'read')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            ylabel='events',
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=4000, h_x=1)
plt.savefig('kf_err_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(128,0,200)", "kf_err==0", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
            fraction=0.47,
             info_coords=(0.0,-1.0),
            h_y=200, h_x=50)
plt.savefig('kf_chi2_simhypo_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("in_mks>>in_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks(512,0.4,0.6)", "kf_err==0", "goff")
draw_1d_hists([('kf_vtx_mks', 'vertex fit'), 
               ('kf_mks', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
              fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=200, h_x=0.05)
plt.savefig('kf_mks_simhypo_xkpi.eps',  bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fl.kf_data.Draw("kf_vtx0[0]-sim_ee_vtx[0]>>kf_vtx0_dx(160, -0.4, 0.4)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx0_dx", 
             xlabel='$\Delta{x}_1$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            h_y=200, h_x=0.2)
plt.savefig("kf_vtx_dx1_simhypo_xkpi.eps", bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx0[1]-sim_ee_vtx[1]>>kf_vtx0_dy(160, -0.4, 0.4)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx0_dy", 
             xlabel='$\Delta{y}_1$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            h_y=200, h_x=0.2)
plt.savefig("kf_vtx_dy1_simhypo_xkpi.eps", bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx0[2]-sim_ee_vtx[2]>>kf_vtx0_dz(160, -4.0, 4.0)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx0_dz", 
             xlabel='$\Delta{z}_1$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            h_y=200, h_x=2.0)
plt.savefig("kf_vtx_dz1_simhypo_xkpi.eps", bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx1[0]-sim_ks_vtx[0]>>kf_vtx1_dx(160, -0.4, 0.4)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx1_dx", 
             xlabel='$\Delta{x}_2$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -0.99),
            h_y=200, h_x=0.2)
plt.savefig("kf_vtx_dx2_simhypo_xkpi.eps", bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx1[1]-sim_ks_vtx[1]>>kf_vtx1_dy(160, -0.4, 0.4)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx1_dy", 
             xlabel='$\Delta{y}_2$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            h_y=200, h_x=0.2)
plt.savefig("kf_vtx_dy2_simhypo_xkpi.eps", bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx1[2]-sim_ks_vtx[2]>>kf_vtx1_dz(160, -4.0, 4.0)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx1_dz", 
             xlabel='$\Delta{z}_2$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -0.99),
            h_y=200, h_x=2)
plt.savefig("kf_vtx_dz2_simhypo_xkpi.eps", bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx0[0]>>kf_vtx0_x(256, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx0[1]>>kf_vtx0_y(256, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx0[2]>>kf_vtx0_z(256, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[0]>>kf_vtx1_x(256, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[1]>>kf_vtx1_y(256, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[2]>>kf_vtx1_z(256, -10, 10)", "kf_err==0", "goff")
vertices_plot2([['kf_vtx0_x', 'kf_vtx1_x'], 
               ['kf_vtx0_y', 'kf_vtx1_y'],
               ['kf_vtx0_z', 'kf_vtx1_z']],
               hspace=0.4,
               wspace=0.4,
            info_coords=(0.6, 0.6),
              hs_y=[[2000, 500], [2000, 500], [50, 50]],
              hs_x=[[5, 5], [5, 5], [5, 5]])
plt.savefig("kskpi_vtx0_vtx1_xyz.eps")

# %%
fl.kf_data.Draw("(kf_vtx0[0]-sim_ee_vtx[0])/sigma_x_vtx0 >>kf_vtx_dx1(100, -20, 20)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dx1", 
             xlabel=r'$\Delta x_{1}/\sqrt{\text{Var}(x^{\text{fit}}_1)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
           h_y=500, h_x=10.0)
plt.savefig('pull_x1_simhypo_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx0[1]-sim_ee_vtx[1])/sigma_y_vtx0 >>kf_vtx_dy1(100, -20, 20)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dy1", 
             xlabel=r'$\Delta y_{1}/\sqrt{\text{Var}(y^{\text{fit}}_1)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
           h_y=500, h_x=10.0)
plt.savefig('pull_y1_simhypo_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx0[2]-sim_ee_vtx[2])/sigma_z_vtx0 >>kf_vtx_dz1(40, -20, 20)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dz1", 
             xlabel=r'$\Delta z_{1}/\sqrt{\text{Var}(z^{\text{fit}}_1)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
           h_y=500, h_x=10.0)
plt.savefig('pull_z1_simhypo_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx1[0]-sim_ks_vtx[0])/sigma_x_vtx1 >>kf_vtx_dx2(100, -20.0, 20.0)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dx2", 
             xlabel=r'$\Delta x_{2} / \sqrt{\text{Var}(x^{\text{fit}}_2)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=500, h_x=10.0)
plt.savefig('pull_x2_simhypo_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx1[1]-sim_ks_vtx[1])/sigma_y_vtx1>>kf_vtx_dy2(100, -20.0, 20.0)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dy2", 
             xlabel=r'$\Delta y_{2} / \sqrt{\text{Var}(y^{\text{fit}}_2)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=500, h_x=10.0)
plt.savefig('pull_y2_simhypo_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx1[2]-sim_ks_vtx[2])/sigma_z_vtx1>>kf_vtx_dz2(40, -20., 20.)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dz2", 
             xlabel=r'$\Delta z_{2} / \sqrt{\text{Var}(z^{\text{fit}}_2)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=500, h_x=10.0)
plt.savefig('pull_z2_simhypo_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx_dr>>kf_vtx_dr(128, 0, 15)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dr", 
             xlabel=r'$\Delta r_{\text{fit}}$ (cm)',
            fraction=0.47,
            info_coords=(0.3, 0.3))
# plt.savefig('kf_vtx_dr_simhypo_xkpi.eps')

# %%
cnv = TCanvas()
fl.kf_data.Draw("kf_vtx_dr", "kf_err==0")
fl.kf_data.Draw("kf_vtx_dr", "kf_err==0 && numiters>6", "same")
cnv.Draw()

# %%
fl.kf_data.Draw("kf_ks_decay_prod_angle>>kf_angle(32, 0, 3.14159)", "", "goff")
draw_1d_hist("kf_angle", xlabel=r'$\alpha$ (rad)')
plt.savefig('kf_ks_prod_angle_kskpi.eps')

# %%
fl.kf_data.Draw("kf_vtx_drho>>kf_vtx_drho(128, 0, 15)", "", "goff")
draw_1d_hist("kf_vtx_drho", xlabel=r'$\Delta\rho$ (cm)')
plt.savefig('kf_vtx_drho_kskpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_K:kf_p_vtx0_K>>pdedx_K(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_K', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_K_from_vtx0_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_pi:kf_p_vtx0_pi>>pdedx_vtx0_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx0_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx0_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx1_pi[0]:kf_p_vtx1_pi[0]>>pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_dedx_vtx1_pi[1]:kf_p_vtx1_pi[1]>>+pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx1_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx1_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("(kf_vtx_dr-sim_vtx_dr)>>kf_delta_dr(512, -2, 2)", "kf_err==0", "goff")
draw_1d_hist("kf_delta_dr", 
             xlabel=r'$\Delta r_{\text{fit}}-\Delta r_{\text{sim}}$ (cm)',
            fraction=0.8,
            info_coords=(0.55, 0.5))
plt.savefig('kf_sim_vs_kf_dr_1d_xkpi.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0 && kf_chi2<100", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr_chi2_100.eps')

# %%
fl.kf_data.Draw("numiters>>numiters", "kf_err==0 && numiters==6", "goff")
draw_1d_hist("numiters", xlabel=r'number of iterations')

# %%
i2 = 2384 / 20519
i3 = 11030 / 20519
i4 = 3996 / 20519
i5 = 1231 / 20519
i6 = 543 / 20519
print(i2 + i3 + i4 + i5 + i6)
# Out:
# 0.934938349822116

# %%
# fl.Close()
