# %%
from run_kinfit import run_kinfit, build_custom_hypo
from draw_funcs import draw_1d_hist, draw_1d_hists, vertices_plot2, draw_2d_hist, draw_scatter
from ROOT import TFile, TCanvas
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.26/08

# %%
build_custom_hypo('Hypo2PiVertex.cpp')
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/Hypo2PiVertex_cpp.so

# %%
input_path = "/var/kinfit/data/tr_ph_run049912.root"
output_path = "kinfit_kskpi_run049912.root"

# %%
run_kinfit(input_path, output_path=output_path, mfield=1.0)
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# (TFile &) Name: /var/kinfit/data/tr_ph_run049912.root Title:
# (TrPh &) @0x7f63c324d000
#  [STATUS : 01%]	CPU TIME: 6.710	REAL TIME: 6.704
#  [STATUS : 02%]	CPU TIME: 6.160	REAL TIME: 6.162
#  [STATUS : 03%]	CPU TIME: 7.170	REAL TIME: 7.156
#  [STATUS : 04%]	CPU TIME: 5.210	REAL TIME: 5.208
#  [STATUS : 05%]	CPU TIME: 5.670	REAL TIME: 5.670
#  [STATUS : 06%]	CPU TIME: 5.630	REAL TIME: 5.626
#  [STATUS : 07%]	CPU TIME: 5.680	REAL TIME: 5.683
#  [STATUS : 08%]	CPU TIME: 6.300	REAL TIME: 6.288
#  [STATUS : 09%]	CPU TIME: 5.780	REAL TIME: 5.777
#  [STATUS : 10%]	CPU TIME: 6.400	REAL TIME: 6.400
#  [STATUS : 11%]	CPU TIME: 6.320	REAL TIME: 6.320
#  [STATUS : 12%]	CPU TIME: 6.480	REAL TIME: 6.473
#  [STATUS : 13%]	CPU TIME: 5.830	REAL TIME: 5.819
#  [STATUS : 14%]	CPU TIME: 5.650	REAL TIME: 5.652
#  [STATUS : 15%]	CPU TIME: 5.740	REAL TIME: 5.725
#  [STATUS : 16%]	CPU TIME: 5.450	REAL TIME: 5.454
#  [STATUS : 17%]	CPU TIME: 6.160	REAL TIME: 6.157
#  [STATUS : 18%]	CPU TIME: 6.170	REAL TIME: 6.160
#  [STATUS : 19%]	CPU TIME: 5.970	REAL TIME: 5.965
#  [STATUS : 20%]	CPU TIME: 4.870	REAL TIME: 4.869
#  [STATUS : 21%]	CPU TIME: 5.970	REAL TIME: 5.968
#  [STATUS : 22%]	CPU TIME: 5.290	REAL TIME: 5.283
#  [STATUS : 23%]	CPU TIME: 5.390	REAL TIME: 5.395
#  [STATUS : 24%]	CPU TIME: 5.150	REAL TIME: 5.139
#  [STATUS : 25%]	CPU TIME: 5.410	REAL TIME: 5.408
#  [STATUS : 26%]	CPU TIME: 5.320	REAL TIME: 5.319
#  [STATUS : 27%]	CPU TIME: 5.600	REAL TIME: 5.599
#  [STATUS : 28%]	CPU TIME: 5.400	REAL TIME: 5.391
#  [STATUS : 29%]	CPU TIME: 5.450	REAL TIME: 5.440
#  [STATUS : 30%]	CPU TIME: 6.050	REAL TIME: 6.049
#  [STATUS : 31%]	CPU TIME: 5.650	REAL TIME: 5.657
#  [STATUS : 32%]	CPU TIME: 5.160	REAL TIME: 5.146
#  [STATUS : 33%]	CPU TIME: 5.880	REAL TIME: 5.888
#  [STATUS : 34%]	CPU TIME: 6.070	REAL TIME: 6.072
#  [STATUS : 35%]	CPU TIME: 5.890	REAL TIME: 5.875
#  [STATUS : 36%]	CPU TIME: 5.570	REAL TIME: 5.569
#  [STATUS : 37%]	CPU TIME: 5.670	REAL TIME: 5.669
#  [STATUS : 38%]	CPU TIME: 5.410	REAL TIME: 5.403
#  [STATUS : 39%]	CPU TIME: 6.300	REAL TIME: 6.298
#  [STATUS : 40%]	CPU TIME: 6.160	REAL TIME: 6.163
#  [STATUS : 41%]	CPU TIME: 6.410	REAL TIME: 6.413
#  [STATUS : 42%]	CPU TIME: 6.880	REAL TIME: 6.882
#  [STATUS : 43%]	CPU TIME: 6.110	REAL TIME: 6.104
#  [STATUS : 44%]	CPU TIME: 5.440	REAL TIME: 5.425
#  [STATUS : 45%]	CPU TIME: 5.700	REAL TIME: 5.698
#  [STATUS : 46%]	CPU TIME: 6.280	REAL TIME: 6.275
#  [STATUS : 47%]	CPU TIME: 7.070	REAL TIME: 7.089
#  [STATUS : 48%]	CPU TIME: 7.130	REAL TIME: 7.132
#  [STATUS : 49%]	CPU TIME: 7.750	REAL TIME: 7.756
#  [STATUS : 50%]	CPU TIME: 7.770	REAL TIME: 7.775
#  [STATUS : 51%]	CPU TIME: 6.760	REAL TIME: 6.754
#  [STATUS : 52%]	CPU TIME: 6.320	REAL TIME: 6.331
#  [STATUS : 53%]	CPU TIME: 6.260	REAL TIME: 6.252
#  [STATUS : 54%]	CPU TIME: 6.790	REAL TIME: 6.799
#  [STATUS : 55%]	CPU TIME: 6.710	REAL TIME: 6.705
#  [STATUS : 56%]	CPU TIME: 6.110	REAL TIME: 6.111
#  [STATUS : 57%]	CPU TIME: 5.800	REAL TIME: 5.807
#  [STATUS : 58%]	CPU TIME: 6.320	REAL TIME: 6.330
#  [STATUS : 59%]	CPU TIME: 6.770	REAL TIME: 6.789
#  [STATUS : 60%]	CPU TIME: 6.590	REAL TIME: 6.583
#  [STATUS : 61%]	CPU TIME: 5.910	REAL TIME: 5.901
#  [STATUS : 62%]	CPU TIME: 5.890	REAL TIME: 5.900
#  [STATUS : 63%]	CPU TIME: 6.910	REAL TIME: 6.914
#  [STATUS : 64%]	CPU TIME: 6.200	REAL TIME: 6.188
#  [STATUS : 65%]	CPU TIME: 5.520	REAL TIME: 5.519
#  [STATUS : 66%]	CPU TIME: 6.960	REAL TIME: 6.963
#  [STATUS : 67%]	CPU TIME: 5.730	REAL TIME: 5.733
#  [STATUS : 68%]	CPU TIME: 5.900	REAL TIME: 5.906
#  [STATUS : 69%]	CPU TIME: 6.320	REAL TIME: 6.324
#  [STATUS : 70%]	CPU TIME: 5.310	REAL TIME: 5.308
#  [STATUS : 71%]	CPU TIME: 6.420	REAL TIME: 6.408
#  [STATUS : 72%]	CPU TIME: 6.360	REAL TIME: 6.359
#  [STATUS : 73%]	CPU TIME: 7.010	REAL TIME: 6.999
#  [STATUS : 74%]	CPU TIME: 6.450	REAL TIME: 6.452
#  [STATUS : 75%]	CPU TIME: 7.090	REAL TIME: 7.101
#  [STATUS : 76%]	CPU TIME: 5.990	REAL TIME: 5.978
#  [STATUS : 77%]	CPU TIME: 7.180	REAL TIME: 7.184
#  [STATUS : 78%]	CPU TIME: 6.220	REAL TIME: 6.221
#  [STATUS : 79%]	CPU TIME: 6.250	REAL TIME: 6.245
#  [STATUS : 80%]	CPU TIME: 6.310	REAL TIME: 6.314
#  [STATUS : 81%]	CPU TIME: 5.900	REAL TIME: 5.905
#  [STATUS : 82%]	CPU TIME: 6.310	REAL TIME: 6.312
#  [STATUS : 83%]	CPU TIME: 5.740	REAL TIME: 5.725
#  [STATUS : 84%]	CPU TIME: 6.790	REAL TIME: 6.794
#  [STATUS : 85%]	CPU TIME: 6.150	REAL TIME: 6.158
#  [STATUS : 86%]	CPU TIME: 5.680	REAL TIME: 5.675
#  [STATUS : 87%]	CPU TIME: 6.670	REAL TIME: 6.672
#  [STATUS : 88%]	CPU TIME: 5.540	REAL TIME: 5.532
#  [STATUS : 89%]	CPU TIME: 6.630	REAL TIME: 6.629
#  [STATUS : 90%]	CPU TIME: 5.660	REAL TIME: 5.653
#  [STATUS : 91%]	CPU TIME: 6.390	REAL TIME: 6.396
#  [STATUS : 92%]	CPU TIME: 7.560	REAL TIME: 7.588
#  [STATUS : 93%]	CPU TIME: 6.460	REAL TIME: 6.458
#  [STATUS : 94%]	CPU TIME: 5.900	REAL TIME: 5.891
#  [STATUS : 95%]	CPU TIME: 5.810	REAL TIME: 5.803
#  [STATUS : 96%]	CPU TIME: 6.730	REAL TIME: 6.723
#  [STATUS : 97%]	CPU TIME: 6.370	REAL TIME: 6.376
#  [STATUS : 98%]	CPU TIME: 5.050	REAL TIME: 5.045
#  [STATUS : 99%]	CPU TIME: 6.360	REAL TIME: 6.358
# _________________________________________
# TOTAL NUMBER OF EVENTS BEFORE CUTS:	100000
# NUBER OF EVENTS TO THE INPUT OF KINFIT:	21660
# NUMBER OF EVENTS PASSED e+e- --> KsK+pi- HYPO:	10314
# NUMBER OF EVENTS PASSED e+e- --> KsK-pi+ HYPO:	10474
# NUMBER OF EVENTS PASSED e+e- --> KsK+-pi-+ HYPOS:	20788
# TOTAL CPU TIME :	612.770
# TOTAL REAL TIME :	612.670
# _________________________________________
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh_C.so
# In file included from /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh_C_ACLiC_dict.cxx:41:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C: In member function ‘virtual void TrPh::Loop(const std::string&, double)’:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:289:10: warning: ‘v_sigma_z_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   289 |   double v_sigma_z_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:288:10: warning: ‘v_sigma_y_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   288 |   double v_sigma_y_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:287:10: warning: ‘v_sigma_x_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   287 |   double v_sigma_x_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:286:10: warning: ‘v_sigma_z_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   286 |   double v_sigma_z_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:285:10: warning: ‘v_sigma_y_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   285 |   double v_sigma_y_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:284:10: warning: ‘v_sigma_x_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   284 |   double v_sigma_x_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:282:10: warning: ‘v_sigma_z_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   282 |   double v_sigma_z_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:281:10: warning: ‘v_sigma_y_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   281 |   double v_sigma_y_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:280:10: warning: ‘v_sigma_x_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   280 |   double v_sigma_x_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:279:10: warning: ‘v_sigma_z_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   279 |   double v_sigma_z_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:278:10: warning: ‘v_sigma_y_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   278 |   double v_sigma_y_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:277:10: warning: ‘v_sigma_x_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   277 |   double v_sigma_x_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# In file included from /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh_C_ACLiC_dict.cxx:41:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C: In member function ‘virtual void TrPh::Loop(const std::string&, double)’:
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:289:10: warning: ‘v_sigma_z_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   289 |   double v_sigma_z_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:288:10: warning: ‘v_sigma_y_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   288 |   double v_sigma_y_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:287:10: warning: ‘v_sigma_x_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   287 |   double v_sigma_x_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:286:10: warning: ‘v_sigma_z_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   286 |   double v_sigma_z_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:285:10: warning: ‘v_sigma_y_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   285 |   double v_sigma_y_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:284:10: warning: ‘v_sigma_x_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   284 |   double v_sigma_x_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:282:10: warning: ‘v_sigma_z_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   282 |   double v_sigma_z_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:281:10: warning: ‘v_sigma_y_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   281 |   double v_sigma_y_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:280:10: warning: ‘v_sigma_x_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   280 |   double v_sigma_x_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:279:10: warning: ‘v_sigma_z_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   279 |   double v_sigma_z_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:278:10: warning: ‘v_sigma_y_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   278 |   double v_sigma_y_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/minor_revision/KsKpi/simhypo_novtxsigma/TrPh.C:277:10: warning: ‘v_sigma_x_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   277 |   double v_sigma_x_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~

# %%
fl = TFile.Open(output_path, 'read')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            ylabel='events',
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=4000, h_x=1)
plt.savefig('kf_err_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(128,0,200)", "kf_err==0", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
            fraction=0.47,
             info_coords=(0.0,-1.0),
            h_y=200, h_x=50)
plt.savefig('kf_chi2_simhypo_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("in_mks>>in_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks(512,0.4,0.6)", "kf_err==0", "goff")
draw_1d_hists([('kf_vtx_mks', 'vertex fit'), 
               ('kf_mks', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
              fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=200, h_x=0.05)
plt.savefig('kf_mks_simhypo_xkpi.eps',  bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fl.kf_data.Draw("kf_vtx0[0]>>kf_vtx0_x(256, -0.4, 0.4)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx0_x", 
             xlabel='$x_1$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            h_y=5000, h_x=0.2)
plt.savefig("kskpi_vtx0_x.eps")

# %%
fl.kf_data.Draw("kf_vtx0[1]>>kf_vtx0_y(256, -0.4, 0.4)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx0_y", 
             xlabel='$y_1$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            h_y=5000, h_x=0.2)
plt.savefig("kskpi_vtx0_y.eps")

# %%
fl.kf_data.Draw("kf_vtx0[2]>>kf_vtx0_z(256, -20.0, 20.0)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx0_z", 
             xlabel='$z_1$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            h_y=200, h_x=10.0)
plt.savefig("kskpi_vtx0_z.eps")

# %%
fl.kf_data.Draw("kf_vtx1[0]>>kf_vtx1_x(256, -10, 10)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx1_x", 
             xlabel='$x_2$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            h_y=200, h_x=2)
plt.savefig("kskpi_vtx1_x.eps")

# %%
fl.kf_data.Draw("kf_vtx1[1]>>kf_vtx1_y(256, -10, 10)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx1_y", 
             xlabel='$y_2$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            h_y=200, h_x=2)
plt.savefig("kskpi_vtx1_y.eps")

# %%
fl.kf_data.Draw("kf_vtx1[2]>>kf_vtx1_z(256, -20, 20)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx1_z", 
             xlabel='$z_2$ (cm)',
            ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            h_y=200, h_x=5)
plt.savefig("kskpi_vtx1_z.eps")

# %%
fl.kf_data.Draw("kf_vtx0[0]>>kf_vtx0_x(256, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx0[1]>>kf_vtx0_y(256, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx0[2]>>kf_vtx0_z(256, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[0]>>kf_vtx1_x(256, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[1]>>kf_vtx1_y(256, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[2]>>kf_vtx1_z(256, -10, 10)", "kf_err==0", "goff")
vertices_plot2([['kf_vtx0_x', 'kf_vtx1_x'], 
               ['kf_vtx0_y', 'kf_vtx1_y'],
               ['kf_vtx0_z', 'kf_vtx1_z']],
               hspace=0.4,
               wspace=0.4,
            info_coords=(0.6, 0.6),
              hs_y=[[2000, 500], [2000, 500], [50, 50]],
              hs_x=[[5, 5], [5, 5], [5, 5]])
plt.savefig("kskpi_vtx0_vtx1_xyz.eps")

# %%
fl.kf_data.Draw("(kf_vtx0[0]-sim_ee_vtx[0])/sigma_x_vtx0 >>kf_vtx_dx1(128, -20, 20)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dx1", 
             xlabel=r'$\Delta x_{1}/\sqrt{\text{var}(x^{\text{fit}}_1)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
           h_y=200, h_x=10.0)
plt.savefig('kskpi_vtxsigma_vtx0_dx_pull.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx0[1]-sim_ee_vtx[1])/sigma_y_vtx0 >>kf_vtx_dy1(128, -20, 20)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dy1", 
             xlabel=r'$\Delta y_{1}/\sqrt{\text{var}(y^{\text{fit}}_1)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
           h_y=200, h_x=10.0)
plt.savefig('kskpi_vtxsigma_vtx0_dy_pull.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx0[2]-sim_ee_vtx[2])/sigma_z_vtx0 >>kf_vtx_dz1(128, -20, 20)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dz1", 
             xlabel=r'$\Delta z_{1}/\sqrt{\text{var}(z^{\text{fit}}_1)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
           h_y=100, h_x=10.0)
plt.savefig('kskpi_vtxsigma_vtx0_dz_pull.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx1[0]-sim_ks_vtx[0])/sigma_x_vtx1 >>kf_vtx_dx2(128, -10.0, 10.0)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dx2", 
             xlabel=r'$\Delta x_{2} / \sqrt{\text{var}(x^{\text{fit}}_2)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=200, h_x=5.0)
plt.savefig('kskpi_vtxsigma_vtx1_dx_pull.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx1[1]-sim_ks_vtx[1])/sigma_y_vtx1>>kf_vtx_dy2(128, -10.0, 10.0)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dy2", 
             xlabel=r'$\Delta y_{2} / \sqrt{\text{var}(y^{\text{fit}}_2)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=200, h_x=5.0)
plt.savefig('kskpi_vtxsigma_vtx1_dy_pull.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx1[2]-sim_ks_vtx[2])/sigma_z_vtx1>>kf_vtx_dz2(128, -20., 20.)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dz2", 
             xlabel=r'$\Delta z_{2} / \sqrt{\text{var}(z^{\text{fit}}_2)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=100, h_x=10.0)
plt.savefig('kskpi_vtxsigma_vtx1_dz_pull.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx_dr>>kf_vtx_dr(128, 0, 15)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dr", 
             xlabel=r'$\Delta r_{\text{fit}}$ (cm)',
            fraction=0.47,
            info_coords=(0.3, 0.3))
# plt.savefig('kf_vtx_dr_simhypo_xkpi.eps')

# %%
cnv = TCanvas()
fl.kf_data.Draw("kf_vtx_dr", "kf_err==0")
fl.kf_data.Draw("kf_vtx_dr", "kf_err==0 && numiters>6", "same")
cnv.Draw()

# %%
fl.kf_data.Draw("kf_ks_decay_prod_angle>>kf_angle(32, 0, 3.14159)", "", "goff")
draw_1d_hist("kf_angle", xlabel=r'$\alpha$ (rad)')
plt.savefig('kf_ks_prod_angle_kskpi.eps')

# %%
fl.kf_data.Draw("kf_vtx_drho>>kf_vtx_drho(128, 0, 15)", "", "goff")
draw_1d_hist("kf_vtx_drho", xlabel=r'$\Delta\rho$ (cm)')
plt.savefig('kf_vtx_drho_kskpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_K:kf_p_vtx0_K>>pdedx_K(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_K', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_K_from_vtx0_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_pi:kf_p_vtx0_pi>>pdedx_vtx0_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx0_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx0_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx1_pi[0]:kf_p_vtx1_pi[0]>>pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_dedx_vtx1_pi[1]:kf_p_vtx1_pi[1]>>+pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx1_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx1_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("(kf_vtx_dr-sim_vtx_dr)>>kf_delta_dr(512, -2, 2)", "kf_err==0", "goff")
draw_1d_hist("kf_delta_dr", 
             xlabel=r'$\Delta r_{\text{fit}}-\Delta r_{\text{sim}}$ (cm)',
            fraction=0.8,
            info_coords=(0.55, 0.5))
plt.savefig('kf_sim_vs_kf_dr_1d_xkpi.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0 && kf_chi2<100", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr_chi2_100.eps')

# %%
fl.kf_data.Draw("numiters>>numiters", "kf_err==0 && numiters==6", "goff")
draw_1d_hist("numiters", xlabel=r'number of iterations')

# %%
i2 = 2384 / 20519
i3 = 11030 / 20519
i4 = 3996 / 20519
i5 = 1231 / 20519
i6 = 543 / 20519
print(i2 + i3 + i4 + i5 + i6)
# Out:
# 0.934938349822116

# %%
# fl.Close()
