# %%
from run_kinfit import run_kinfit, build_custom_hypo
from draw_funcs import draw_1d_hist, draw_1d_hists, vertices_plot2, draw_2d_hist, draw_scatter
from ROOT import TFile, TCanvas
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.26/08

# %%
build_custom_hypo('Hypo2PiVertex.cpp',
                  rootlogon_path='/home/hep/packages/kfcmd_tr_ph_v8/share/kfcmd/rootlogon.C')
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/isr/KsKpi_sim_hypo_vertex_fit/Hypo2PiVertex_cpp.so

# %%
input_path = "/var/kinfit/data/tr_ph_run068706.root"
output_path = "kinfit_kskpi_run068706.root"

# %%
run_kinfit(input_path, output_path=output_path, mfield=1.0,
          rootlogon_path='/home/hep/packages/kfcmd_tr_ph_v8/share/kfcmd/rootlogon.C')
# 21281
# KsK+pi- 10174
# KsK-pi+ 10345
# KsKpi 20519
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# (TFile &) Name: /var/kinfit/data/tr_ph_run068706.root Title:
# (TrPh &) @0x7f1080591000
#  [STATUS : 01%]	CPU TIME: 6.620	REAL TIME: 6.616
#  [STATUS : 02%]	CPU TIME: 5.870	REAL TIME: 5.867
#  [STATUS : 03%]	CPU TIME: 5.760	REAL TIME: 5.760
#  [STATUS : 04%]	CPU TIME: 6.390	REAL TIME: 6.381
#  [STATUS : 05%]	CPU TIME: 5.760	REAL TIME: 5.753
#  [STATUS : 06%]	CPU TIME: 5.480	REAL TIME: 5.476
#  [STATUS : 07%]	CPU TIME: 5.890	REAL TIME: 5.879
#  [STATUS : 08%]	CPU TIME: 5.480	REAL TIME: 5.489
#  [STATUS : 09%]	CPU TIME: 5.210	REAL TIME: 5.200
#  [STATUS : 10%]	CPU TIME: 6.270	REAL TIME: 6.262
#  [STATUS : 11%]	CPU TIME: 5.670	REAL TIME: 5.663
#  [STATUS : 12%]	CPU TIME: 5.240	REAL TIME: 5.238
#  [STATUS : 13%]	CPU TIME: 6.300	REAL TIME: 6.289
#  [STATUS : 14%]	CPU TIME: 6.140	REAL TIME: 6.127
#  [STATUS : 15%]	CPU TIME: 5.740	REAL TIME: 5.736
#  [STATUS : 16%]	CPU TIME: 5.940	REAL TIME: 5.940
#  [STATUS : 17%]	CPU TIME: 6.120	REAL TIME: 6.111
#  [STATUS : 18%]	CPU TIME: 5.710	REAL TIME: 5.704
#  [STATUS : 19%]	CPU TIME: 5.520	REAL TIME: 5.523
#  [STATUS : 20%]	CPU TIME: 5.610	REAL TIME: 5.593
#  [STATUS : 21%]	CPU TIME: 6.070	REAL TIME: 6.062
#  [STATUS : 22%]	CPU TIME: 5.210	REAL TIME: 5.204
#  [STATUS : 23%]	CPU TIME: 5.330	REAL TIME: 5.335
#  [STATUS : 24%]	CPU TIME: 6.270	REAL TIME: 6.253
#  [STATUS : 25%]	CPU TIME: 6.440	REAL TIME: 6.428
#  [STATUS : 26%]	CPU TIME: 5.880	REAL TIME: 5.875
#  [STATUS : 27%]	CPU TIME: 5.260	REAL TIME: 5.253
#  [STATUS : 28%]	CPU TIME: 5.930	REAL TIME: 5.933
#  [STATUS : 29%]	CPU TIME: 5.570	REAL TIME: 5.558
#  [STATUS : 30%]	CPU TIME: 5.880	REAL TIME: 5.881
#  [STATUS : 31%]	CPU TIME: 5.130	REAL TIME: 5.119
#  [STATUS : 32%]	CPU TIME: 5.560	REAL TIME: 5.549
#  [STATUS : 33%]	CPU TIME: 6.330	REAL TIME: 6.321
#  [STATUS : 34%]	CPU TIME: 6.160	REAL TIME: 6.157
#  [STATUS : 35%]	CPU TIME: 5.600	REAL TIME: 5.589
#  [STATUS : 36%]	CPU TIME: 5.350	REAL TIME: 5.355
#  [STATUS : 37%]	CPU TIME: 5.800	REAL TIME: 5.787
#  [STATUS : 38%]	CPU TIME: 5.680	REAL TIME: 5.670
#  [STATUS : 39%]	CPU TIME: 5.410	REAL TIME: 5.410
#  [STATUS : 40%]	CPU TIME: 5.510	REAL TIME: 5.507
#  [STATUS : 41%]	CPU TIME: 5.910	REAL TIME: 5.902
#  [STATUS : 42%]	CPU TIME: 5.780	REAL TIME: 5.770
#  [STATUS : 43%]	CPU TIME: 5.720	REAL TIME: 5.710
#  [STATUS : 44%]	CPU TIME: 5.620	REAL TIME: 5.611
#  [STATUS : 45%]	CPU TIME: 5.520	REAL TIME: 5.527
#  [STATUS : 46%]	CPU TIME: 5.370	REAL TIME: 5.357
#  [STATUS : 47%]	CPU TIME: 5.090	REAL TIME: 5.089
#  [STATUS : 48%]	CPU TIME: 6.430	REAL TIME: 6.414
#  [STATUS : 49%]	CPU TIME: 5.640	REAL TIME: 5.629
#  [STATUS : 50%]	CPU TIME: 5.790	REAL TIME: 5.785
#  [STATUS : 51%]	CPU TIME: 6.650	REAL TIME: 6.645
#  [STATUS : 52%]	CPU TIME: 5.080	REAL TIME: 5.080
#  [STATUS : 53%]	CPU TIME: 5.550	REAL TIME: 5.539
#  [STATUS : 54%]	CPU TIME: 5.500	REAL TIME: 5.500
#  [STATUS : 55%]	CPU TIME: 6.190	REAL TIME: 6.187
#  [STATUS : 56%]	CPU TIME: 5.430	REAL TIME: 5.422
#  [STATUS : 57%]	CPU TIME: 5.500	REAL TIME: 5.497
#  [STATUS : 58%]	CPU TIME: 5.650	REAL TIME: 5.647
#  [STATUS : 59%]	CPU TIME: 5.490	REAL TIME: 5.474
#  [STATUS : 60%]	CPU TIME: 6.640	REAL TIME: 6.640
#  [STATUS : 61%]	CPU TIME: 5.950	REAL TIME: 5.941
#  [STATUS : 62%]	CPU TIME: 5.030	REAL TIME: 5.037
#  [STATUS : 63%]	CPU TIME: 5.520	REAL TIME: 5.519
#  [STATUS : 64%]	CPU TIME: 5.850	REAL TIME: 5.843
#  [STATUS : 65%]	CPU TIME: 5.570	REAL TIME: 5.565
#  [STATUS : 66%]	CPU TIME: 5.680	REAL TIME: 5.670
#  [STATUS : 67%]	CPU TIME: 5.880	REAL TIME: 5.881
#  [STATUS : 68%]	CPU TIME: 5.470	REAL TIME: 5.461
#  [STATUS : 69%]	CPU TIME: 5.610	REAL TIME: 5.607
#  [STATUS : 70%]	CPU TIME: 5.520	REAL TIME: 5.509
#  [STATUS : 71%]	CPU TIME: 5.200	REAL TIME: 5.201
#  [STATUS : 72%]	CPU TIME: 5.640	REAL TIME: 5.629
#  [STATUS : 73%]	CPU TIME: 5.600	REAL TIME: 5.607
#  [STATUS : 74%]	CPU TIME: 5.580	REAL TIME: 5.580
#  [STATUS : 75%]	CPU TIME: 6.150	REAL TIME: 6.146
#  [STATUS : 76%]	CPU TIME: 5.420	REAL TIME: 5.410
#  [STATUS : 77%]	CPU TIME: 5.330	REAL TIME: 5.322
#  [STATUS : 78%]	CPU TIME: 5.660	REAL TIME: 5.647
#  [STATUS : 79%]	CPU TIME: 5.490	REAL TIME: 5.494
#  [STATUS : 80%]	CPU TIME: 5.630	REAL TIME: 5.622
#  [STATUS : 81%]	CPU TIME: 5.470	REAL TIME: 5.475
#  [STATUS : 82%]	CPU TIME: 5.860	REAL TIME: 5.842
#  [STATUS : 83%]	CPU TIME: 5.350	REAL TIME: 5.360
#  [STATUS : 84%]	CPU TIME: 6.100	REAL TIME: 6.098
#  [STATUS : 85%]	CPU TIME: 5.890	REAL TIME: 5.874
#  [STATUS : 86%]	CPU TIME: 5.580	REAL TIME: 5.576
#  [STATUS : 87%]	CPU TIME: 5.910	REAL TIME: 5.898
#  [STATUS : 88%]	CPU TIME: 6.080	REAL TIME: 6.075
#  [STATUS : 89%]	CPU TIME: 5.290	REAL TIME: 5.292
#  [STATUS : 90%]	CPU TIME: 5.160	REAL TIME: 5.160
#  [STATUS : 91%]	CPU TIME: 5.190	REAL TIME: 5.186
#  [STATUS : 92%]	CPU TIME: 5.200	REAL TIME: 5.189
#  [STATUS : 93%]	CPU TIME: 5.500	REAL TIME: 5.493
#  [STATUS : 94%]	CPU TIME: 5.940	REAL TIME: 5.934
#  [STATUS : 95%]	CPU TIME: 5.510	REAL TIME: 5.508
#  [STATUS : 96%]	CPU TIME: 5.640	REAL TIME: 5.628
#  [STATUS : 97%]	CPU TIME: 6.400	REAL TIME: 6.398
#  [STATUS : 98%]	CPU TIME: 6.100	REAL TIME: 6.094
#  [STATUS : 99%]	CPU TIME: 5.450	REAL TIME: 5.445
# _________________________________________
# TOTAL NUMBER OF EVENTS BEFORE CUTS:	100000
# NUBER OF EVENTS TO THE INPUT OF KINFIT:	21536
# NUMBER OF EVENTS PASSED e+e- --> KsK+pi- HYPO:	10306
# NUMBER OF EVENTS PASSED e+e- --> KsK-pi+ HYPO:	10388
# NUMBER OF EVENTS PASSED e+e- --> KsK+-pi-+ HYPOS:	20694
# TOTAL CPU TIME :	570.790
# TOTAL REAL TIME :	570.264
# _________________________________________
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/isr/KsKpi_sim_hypo_vertex_fit/TrPh_C.so

# %%
fl = TFile.Open(output_path, 'read')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            ylabel='events',
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=4000, h_x=1)
plt.savefig('kf_err_simhypo_xkpi_isr.eps')

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(128,0,200)", "kf_err==0", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
            fraction=0.47,
             info_coords=(0.0,-1.0),
            h_y=200, h_x=50)
plt.savefig('kf_chi2_simhypo_xkpi_isr.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("in_mks>>in_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks(512,0.4,0.6)", "kf_err==0", "goff")
draw_1d_hists([('kf_vtx_mks', 'vertex fit'), 
               ('kf_mks', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
              fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=200, h_x=0.05)
plt.savefig('kf_mks_simhypo_xkpi_isr.eps',  bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fl.kf_data.Draw("kf_vtx0[0]>>kf_vtx0_x(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx0[1]>>kf_vtx0_y(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx0[2]>>kf_vtx0_z(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[0]>>kf_vtx1_x(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[1]>>kf_vtx1_y(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[2]>>kf_vtx1_z(256, -10, 10)", "", "goff")
vertices_plot2([['kf_vtx0_x', 'kf_vtx1_x'], 
               ['kf_vtx0_y', 'kf_vtx1_y'],
               ['kf_vtx0_z', 'kf_vtx1_z']],
                info_coords=(0.6, 0.6))

# %%
fl.kf_data.Draw("kf_vtx_dr>>kf_vtx_dr(128, 0, 15)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dr", 
             xlabel=r'$\Delta r_{\text{fit}}$ (cm)',
            fraction=0.47,
            info_coords=(0.3, 0.3))
# plt.savefig('kf_vtx_dr_simhypo_xkpi.eps')

# %%
cnv = TCanvas()
fl.kf_data.Draw("kf_vtx_dr", "kf_err==0")
fl.kf_data.Draw("kf_vtx_dr", "kf_err==0 && numiters>6", "same")
cnv.Draw()

# %%
fl.kf_data.Draw("kf_ks_decay_prod_angle>>kf_angle(32, 0, 3.14159)", "", "goff")
draw_1d_hist("kf_angle", xlabel=r'$\alpha$ (rad)')
plt.savefig('kf_ks_prod_angle_kskpi_isr.eps')

# %%
fl.kf_data.Draw("kf_vtx_drho>>kf_vtx_drho(128, 0, 15)", "", "goff")
draw_1d_hist("kf_vtx_drho", xlabel=r'$\Delta\rho$ (cm)')
plt.savefig('kf_vtx_drho_kskpi_isr.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_K:kf_p_vtx0_K>>pdedx_K(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_K', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_K_from_vtx0_simhypo_xkpi_isr.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_pi:kf_p_vtx0_pi>>pdedx_vtx0_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx0_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx0_simhypo_xkpi_isr.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx1_pi[0]:kf_p_vtx1_pi[0]>>pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_dedx_vtx1_pi[1]:kf_p_vtx1_pi[1]>>+pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx1_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx1_simhypo_xkpi_isr.eps')

# %%
fl.kf_data.Draw("(kf_vtx_dr-sim_vtx_dr)>>kf_delta_dr(512, -2, 2)", "kf_err==0", "goff")
draw_1d_hist("kf_delta_dr", 
             xlabel=r'$\Delta r_{\text{fit}}-\Delta r_{\text{sim}}$ (cm)',
            fraction=0.8,
            info_coords=(0.55, 0.5))
plt.savefig('kf_sim_vs_kf_dr_1d_xkpi_isr.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr_isr.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0 && kf_chi2<100", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr_chi2_100_isr.eps')

# %%
fl.kf_data.Draw("numiters>>numiters", "kf_err==0 && numiters==6", "goff")
draw_1d_hist("numiters", xlabel=r'number of iterations')

# %%
i2 = 2384 / 20519
i3 = 11030 / 20519
i4 = 3996 / 20519
i5 = 1231 / 20519
i6 = 543 / 20519
print(i2 + i3 + i4 + i5 + i6)
# Out:
# 0.934938349822116

# %%
# fl.Close()
