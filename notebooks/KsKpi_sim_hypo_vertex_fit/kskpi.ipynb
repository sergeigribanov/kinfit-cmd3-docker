# %%
from run_kinfit import run_kinfit, build_custom_hypo
from draw_funcs import draw_1d_hist, draw_1d_hists, vertices_plot2, draw_2d_hist, draw_scatter
from ROOT import TFile, TCanvas
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.26/08

# %%
build_custom_hypo('Hypo2PiVertex.cpp')
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/KsKpi_sim_hypo_vertex_fit/Hypo2PiVertex_cpp.so

# %%
input_path = "/var/kinfit/data/tr_ph_run049912.root"
output_path = "kinfit_kskpi_run049912.root"

# %%
run_kinfit(input_path, output_path=output_path, mfield=1.0)
# 21281
# KsK+pi- 10174
# KsK-pi+ 10345
# KsKpi 20519
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# (TFile &) Name: /var/kinfit/data/tr_ph_run049912.root Title:
# (TrPh &) @0x7f84984f6000
#  [STATUS : 01%]	CPU TIME: 7.110	REAL TIME: 7.120
#  [STATUS : 02%]	CPU TIME: 6.530	REAL TIME: 6.537
#  [STATUS : 03%]	CPU TIME: 7.120	REAL TIME: 7.118
#  [STATUS : 04%]	CPU TIME: 5.290	REAL TIME: 5.289
#  [STATUS : 05%]	CPU TIME: 5.450	REAL TIME: 5.440
#  [STATUS : 06%]	CPU TIME: 5.920	REAL TIME: 5.917
#  [STATUS : 07%]	CPU TIME: 5.430	REAL TIME: 5.435
#  [STATUS : 08%]	CPU TIME: 6.020	REAL TIME: 6.017
#  [STATUS : 09%]	CPU TIME: 5.530	REAL TIME: 5.526
#  [STATUS : 10%]	CPU TIME: 6.740	REAL TIME: 6.734
#  [STATUS : 11%]	CPU TIME: 7.070	REAL TIME: 7.071
#  [STATUS : 12%]	CPU TIME: 6.350	REAL TIME: 6.372
#  [STATUS : 13%]	CPU TIME: 6.110	REAL TIME: 6.108
#  [STATUS : 14%]	CPU TIME: 6.030	REAL TIME: 6.023
#  [STATUS : 15%]	CPU TIME: 6.270	REAL TIME: 6.286
#  [STATUS : 16%]	CPU TIME: 6.350	REAL TIME: 6.354
#  [STATUS : 17%]	CPU TIME: 7.040	REAL TIME: 7.048
#  [STATUS : 18%]	CPU TIME: 6.140	REAL TIME: 6.128
#  [STATUS : 19%]	CPU TIME: 6.170	REAL TIME: 6.170
#  [STATUS : 20%]	CPU TIME: 5.840	REAL TIME: 5.863
#  [STATUS : 21%]	CPU TIME: 7.100	REAL TIME: 7.097
#  [STATUS : 22%]	CPU TIME: 5.890	REAL TIME: 5.901
#  [STATUS : 23%]	CPU TIME: 5.900	REAL TIME: 5.891
#  [STATUS : 24%]	CPU TIME: 5.480	REAL TIME: 5.477
#  [STATUS : 25%]	CPU TIME: 7.210	REAL TIME: 7.203
#  [STATUS : 26%]	CPU TIME: 6.090	REAL TIME: 6.099
#  [STATUS : 27%]	CPU TIME: 6.580	REAL TIME: 6.586
#  [STATUS : 28%]	CPU TIME: 6.020	REAL TIME: 6.018
#  [STATUS : 29%]	CPU TIME: 5.840	REAL TIME: 5.841
#  [STATUS : 30%]	CPU TIME: 6.540	REAL TIME: 6.541
#  [STATUS : 31%]	CPU TIME: 6.170	REAL TIME: 6.158
#  [STATUS : 32%]	CPU TIME: 6.210	REAL TIME: 6.215
#  [STATUS : 33%]	CPU TIME: 6.530	REAL TIME: 6.520
#  [STATUS : 34%]	CPU TIME: 6.840	REAL TIME: 6.837
#  [STATUS : 35%]	CPU TIME: 6.530	REAL TIME: 6.530
#  [STATUS : 36%]	CPU TIME: 6.100	REAL TIME: 6.100
#  [STATUS : 37%]	CPU TIME: 6.210	REAL TIME: 6.206
#  [STATUS : 38%]	CPU TIME: 5.930	REAL TIME: 5.930
#  [STATUS : 39%]	CPU TIME: 6.230	REAL TIME: 6.227
#  [STATUS : 40%]	CPU TIME: 5.380	REAL TIME: 5.383
#  [STATUS : 41%]	CPU TIME: 6.110	REAL TIME: 6.101
#  [STATUS : 42%]	CPU TIME: 7.590	REAL TIME: 7.596
#  [STATUS : 43%]	CPU TIME: 6.020	REAL TIME: 6.055
#  [STATUS : 44%]	CPU TIME: 5.550	REAL TIME: 5.550
#  [STATUS : 45%]	CPU TIME: 5.640	REAL TIME: 5.640
#  [STATUS : 46%]	CPU TIME: 6.580	REAL TIME: 6.587
#  [STATUS : 47%]	CPU TIME: 6.760	REAL TIME: 6.802
#  [STATUS : 48%]	CPU TIME: 6.410	REAL TIME: 6.403
#  [STATUS : 49%]	CPU TIME: 6.780	REAL TIME: 6.795
#  [STATUS : 50%]	CPU TIME: 7.280	REAL TIME: 7.283
#  [STATUS : 51%]	CPU TIME: 6.730	REAL TIME: 6.722
#  [STATUS : 52%]	CPU TIME: 6.350	REAL TIME: 6.349
#  [STATUS : 53%]	CPU TIME: 6.470	REAL TIME: 6.469
#  [STATUS : 54%]	CPU TIME: 6.310	REAL TIME: 6.294
#  [STATUS : 55%]	CPU TIME: 6.220	REAL TIME: 6.225
#  [STATUS : 56%]	CPU TIME: 6.230	REAL TIME: 6.221
#  [STATUS : 57%]	CPU TIME: 5.560	REAL TIME: 5.557
#  [STATUS : 58%]	CPU TIME: 6.070	REAL TIME: 6.067
#  [STATUS : 59%]	CPU TIME: 6.550	REAL TIME: 6.561
#  [STATUS : 60%]	CPU TIME: 5.760	REAL TIME: 5.759
#  [STATUS : 61%]	CPU TIME: 5.620	REAL TIME: 5.610
#  [STATUS : 62%]	CPU TIME: 5.660	REAL TIME: 5.658
#  [STATUS : 63%]	CPU TIME: 5.790	REAL TIME: 5.793
#  [STATUS : 64%]	CPU TIME: 5.650	REAL TIME: 5.643
#  [STATUS : 65%]	CPU TIME: 5.190	REAL TIME: 5.193
#  [STATUS : 66%]	CPU TIME: 5.850	REAL TIME: 5.846
#  [STATUS : 67%]	CPU TIME: 5.670	REAL TIME: 5.679
#  [STATUS : 68%]	CPU TIME: 5.980	REAL TIME: 5.974
#  [STATUS : 69%]	CPU TIME: 5.990	REAL TIME: 5.996
#  [STATUS : 70%]	CPU TIME: 5.530	REAL TIME: 5.525
#  [STATUS : 71%]	CPU TIME: 6.740	REAL TIME: 6.740
#  [STATUS : 72%]	CPU TIME: 6.840	REAL TIME: 6.834
#  [STATUS : 73%]	CPU TIME: 7.510	REAL TIME: 7.518
#  [STATUS : 74%]	CPU TIME: 5.810	REAL TIME: 5.819
#  [STATUS : 75%]	CPU TIME: 6.410	REAL TIME: 6.406
#  [STATUS : 76%]	CPU TIME: 5.580	REAL TIME: 5.578
#  [STATUS : 77%]	CPU TIME: 6.740	REAL TIME: 6.740
#  [STATUS : 78%]	CPU TIME: 5.940	REAL TIME: 5.936
#  [STATUS : 79%]	CPU TIME: 5.430	REAL TIME: 5.421
#  [STATUS : 80%]	CPU TIME: 6.090	REAL TIME: 6.088
#  [STATUS : 81%]	CPU TIME: 5.770	REAL TIME: 5.766
#  [STATUS : 82%]	CPU TIME: 6.080	REAL TIME: 6.086
#  [STATUS : 83%]	CPU TIME: 5.880	REAL TIME: 5.870
#  [STATUS : 84%]	CPU TIME: 6.820	REAL TIME: 6.827
#  [STATUS : 85%]	CPU TIME: 6.140	REAL TIME: 6.129
#  [STATUS : 86%]	CPU TIME: 5.900	REAL TIME: 5.909
#  [STATUS : 87%]	CPU TIME: 6.350	REAL TIME: 6.331
#  [STATUS : 88%]	CPU TIME: 5.740	REAL TIME: 5.751
#  [STATUS : 89%]	CPU TIME: 6.760	REAL TIME: 6.755
#  [STATUS : 90%]	CPU TIME: 5.320	REAL TIME: 5.312
#  [STATUS : 91%]	CPU TIME: 6.220	REAL TIME: 6.221
#  [STATUS : 92%]	CPU TIME: 5.590	REAL TIME: 5.590
#  [STATUS : 93%]	CPU TIME: 5.970	REAL TIME: 5.975
#  [STATUS : 94%]	CPU TIME: 5.740	REAL TIME: 5.736
#  [STATUS : 95%]	CPU TIME: 5.490	REAL TIME: 5.480
#  [STATUS : 96%]	CPU TIME: 6.060	REAL TIME: 6.057
#  [STATUS : 97%]	CPU TIME: 5.890	REAL TIME: 5.894
#  [STATUS : 98%]	CPU TIME: 4.720	REAL TIME: 4.718
#  [STATUS : 99%]	CPU TIME: 5.500	REAL TIME: 5.493
# _________________________________________
# TOTAL NUMBER OF EVENTS BEFORE CUTS:	100000
# NUBER OF EVENTS TO THE INPUT OF KINFIT:	21660
# NUMBER OF EVENTS PASSED e+e- --> KsK+pi- HYPO:	10314
# NUMBER OF EVENTS PASSED e+e- --> KsK-pi+ HYPO:	10474
# NUMBER OF EVENTS PASSED e+e- --> KsK+-pi-+ HYPOS:	20788
# TOTAL CPU TIME :	613.690
# TOTAL REAL TIME :	613.727
# _________________________________________
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/KsKpi_sim_hypo_vertex_fit/TrPh_C.so

# %%
fl = TFile.Open(output_path, 'read')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            ylabel='events',
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=4000, h_x=1)
plt.savefig('kf_err_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(128,0,200)", "kf_err==0", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
            fraction=0.47,
             info_coords=(0.0,-1.0),
            h_y=200, h_x=50)
plt.savefig('kf_chi2_simhypo_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("in_mks>>in_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks(512,0.4,0.6)", "kf_err==0", "goff")
draw_1d_hists([('kf_vtx_mks', 'vertex fit'), 
               ('kf_mks', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
              fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=200, h_x=0.05)
plt.savefig('kf_mks_simhypo_xkpi.eps',  bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fl.kf_data.Draw("kf_vtx0[0]>>kf_vtx0_x(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx0[1]>>kf_vtx0_y(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx0[2]>>kf_vtx0_z(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[0]>>kf_vtx1_x(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[1]>>kf_vtx1_y(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[2]>>kf_vtx1_z(256, -10, 10)", "", "goff")
vertices_plot2([['kf_vtx0_x', 'kf_vtx1_x'], 
               ['kf_vtx0_y', 'kf_vtx1_y'],
               ['kf_vtx0_z', 'kf_vtx1_z']],
                info_coords=(0.6, 0.6))

# %%
fl.kf_data.Draw("kf_vtx_dr>>kf_vtx_dr(128, 0, 15)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dr", 
             xlabel=r'$\Delta r_{\text{fit}}$ (cm)',
            fraction=0.47,
            info_coords=(0.3, 0.3))
# plt.savefig('kf_vtx_dr_simhypo_xkpi.eps')

# %%
cnv = TCanvas()
fl.kf_data.Draw("kf_vtx_dr", "kf_err==0")
fl.kf_data.Draw("kf_vtx_dr", "kf_err==0 && numiters>6", "same")
cnv.Draw()

# %%
fl.kf_data.Draw("kf_ks_decay_prod_angle>>kf_angle(32, 0, 3.14159)", "", "goff")
draw_1d_hist("kf_angle", xlabel=r'$\alpha$ (rad)')
plt.savefig('kf_ks_prod_angle_kskpi.eps')

# %%
fl.kf_data.Draw("kf_vtx_drho>>kf_vtx_drho(128, 0, 15)", "", "goff")
draw_1d_hist("kf_vtx_drho", xlabel=r'$\Delta\rho$ (cm)')
plt.savefig('kf_vtx_drho_kskpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_K:kf_p_vtx0_K>>pdedx_K(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_K', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_K_from_vtx0_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_pi:kf_p_vtx0_pi>>pdedx_vtx0_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx0_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx0_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx1_pi[0]:kf_p_vtx1_pi[0]>>pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_dedx_vtx1_pi[1]:kf_p_vtx1_pi[1]>>+pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx1_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx1_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("(kf_vtx_dr-sim_vtx_dr)>>kf_delta_dr(512, -2, 2)", "kf_err==0", "goff")
draw_1d_hist("kf_delta_dr", 
             xlabel=r'$\Delta r_{\text{fit}}-\Delta r_{\text{sim}}$ (cm)',
            fraction=0.8,
            info_coords=(0.55, 0.5))
plt.savefig('kf_sim_vs_kf_dr_1d_xkpi.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0 && kf_chi2<100", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr_chi2_100.eps')

# %%
fl.kf_data.Draw("numiters>>numiters", "kf_err==0 && numiters==6", "goff")
draw_1d_hist("numiters", xlabel=r'number of iterations')

# %%
i2 = 2384 / 20519
i3 = 11030 / 20519
i4 = 3996 / 20519
i5 = 1231 / 20519
i6 = 543 / 20519
print(i2 + i3 + i4 + i5 + i6)
# Out:
# 0.934938349822116

# %%
# fl.Close()
