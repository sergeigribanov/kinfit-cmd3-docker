# %%
from run_kinfit import run_kinfit, build_custom_hypo
from draw_funcs import draw_1d_hist, draw_1d_hists, vertices_plot2, draw_2d_hist, draw_scatter
from ROOT import TFile
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.26/08

# %%
input_path = "/var/kinfit/data/tr_ph_run049912.root"
output_path = "kinfit_kskpi_run049912.root"

# %%
run_kinfit(input_path, output_path=output_path, mfield=1.0)
# 21281
# KsK+pi- 10174
# KsK-pi+ 10345
# KsKpi 20519
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# (TFile &) Name: /var/kinfit/data/tr_ph_run049912.root Title:
# (TrPh &) @0x7fe42cc5c000
#  [STATUS : 01%]	CPU TIME: 6.460	REAL TIME: 6.450
#  [STATUS : 02%]	CPU TIME: 6.080	REAL TIME: 6.104
#  [STATUS : 03%]	CPU TIME: 6.920	REAL TIME: 6.937
#  [STATUS : 04%]	CPU TIME: 5.200	REAL TIME: 5.205
#  [STATUS : 05%]	CPU TIME: 6.110	REAL TIME: 6.110
#  [STATUS : 06%]	CPU TIME: 6.250	REAL TIME: 6.250
#  [STATUS : 07%]	CPU TIME: 6.110	REAL TIME: 6.106
#  [STATUS : 08%]	CPU TIME: 6.560	REAL TIME: 6.564
#  [STATUS : 09%]	CPU TIME: 5.260	REAL TIME: 5.257
#  [STATUS : 10%]	CPU TIME: 6.470	REAL TIME: 6.469
#  [STATUS : 11%]	CPU TIME: 6.320	REAL TIME: 6.328
#  [STATUS : 12%]	CPU TIME: 6.420	REAL TIME: 6.418
#  [STATUS : 13%]	CPU TIME: 6.370	REAL TIME: 6.360
#  [STATUS : 14%]	CPU TIME: 6.000	REAL TIME: 6.004
#  [STATUS : 15%]	CPU TIME: 6.220	REAL TIME: 6.220
#  [STATUS : 16%]	CPU TIME: 5.310	REAL TIME: 5.312
#  [STATUS : 17%]	CPU TIME: 6.220	REAL TIME: 6.207
#  [STATUS : 18%]	CPU TIME: 5.910	REAL TIME: 5.908
#  [STATUS : 19%]	CPU TIME: 5.740	REAL TIME: 5.739
#  [STATUS : 20%]	CPU TIME: 4.760	REAL TIME: 4.757
#  [STATUS : 21%]	CPU TIME: 5.850	REAL TIME: 5.840
#  [STATUS : 22%]	CPU TIME: 5.440	REAL TIME: 5.443
#  [STATUS : 23%]	CPU TIME: 5.610	REAL TIME: 5.597
#  [STATUS : 24%]	CPU TIME: 5.220	REAL TIME: 5.227
#  [STATUS : 25%]	CPU TIME: 5.230	REAL TIME: 5.226
#  [STATUS : 26%]	CPU TIME: 5.450	REAL TIME: 5.447
#  [STATUS : 27%]	CPU TIME: 5.780	REAL TIME: 5.780
#  [STATUS : 28%]	CPU TIME: 5.390	REAL TIME: 5.393
#  [STATUS : 29%]	CPU TIME: 5.430	REAL TIME: 5.422
#  [STATUS : 30%]	CPU TIME: 6.460	REAL TIME: 6.465
#  [STATUS : 31%]	CPU TIME: 5.610	REAL TIME: 5.615
#  [STATUS : 32%]	CPU TIME: 5.020	REAL TIME: 5.020
#  [STATUS : 33%]	CPU TIME: 5.870	REAL TIME: 5.861
#  [STATUS : 34%]	CPU TIME: 5.950	REAL TIME: 5.945
#  [STATUS : 35%]	CPU TIME: 6.130	REAL TIME: 6.142
#  [STATUS : 36%]	CPU TIME: 6.200	REAL TIME: 6.199
#  [STATUS : 37%]	CPU TIME: 5.900	REAL TIME: 5.907
#  [STATUS : 38%]	CPU TIME: 5.170	REAL TIME: 5.158
#  [STATUS : 39%]	CPU TIME: 5.420	REAL TIME: 5.419
#  [STATUS : 40%]	CPU TIME: 4.680	REAL TIME: 4.665
#  [STATUS : 41%]	CPU TIME: 5.090	REAL TIME: 5.084
#  [STATUS : 42%]	CPU TIME: 5.640	REAL TIME: 5.646
#  [STATUS : 43%]	CPU TIME: 5.700	REAL TIME: 5.685
#  [STATUS : 44%]	CPU TIME: 5.130	REAL TIME: 5.130
#  [STATUS : 45%]	CPU TIME: 5.190	REAL TIME: 5.189
#  [STATUS : 46%]	CPU TIME: 5.440	REAL TIME: 5.435
#  [STATUS : 47%]	CPU TIME: 5.540	REAL TIME: 5.535
#  [STATUS : 48%]	CPU TIME: 5.900	REAL TIME: 5.900
#  [STATUS : 49%]	CPU TIME: 5.940	REAL TIME: 5.944
#  [STATUS : 50%]	CPU TIME: 5.800	REAL TIME: 5.791
#  [STATUS : 51%]	CPU TIME: 5.610	REAL TIME: 5.608
#  [STATUS : 52%]	CPU TIME: 5.640	REAL TIME: 5.639
#  [STATUS : 53%]	CPU TIME: 5.190	REAL TIME: 5.188
#  [STATUS : 54%]	CPU TIME: 5.110	REAL TIME: 5.106
#  [STATUS : 55%]	CPU TIME: 5.270	REAL TIME: 5.262
#  [STATUS : 56%]	CPU TIME: 5.120	REAL TIME: 5.122
#  [STATUS : 57%]	CPU TIME: 5.070	REAL TIME: 5.059
#  [STATUS : 58%]	CPU TIME: 5.300	REAL TIME: 5.302
#  [STATUS : 59%]	CPU TIME: 6.250	REAL TIME: 6.237
#  [STATUS : 60%]	CPU TIME: 5.190	REAL TIME: 5.193
#  [STATUS : 61%]	CPU TIME: 5.150	REAL TIME: 5.138
#  [STATUS : 62%]	CPU TIME: 5.130	REAL TIME: 5.131
#  [STATUS : 63%]	CPU TIME: 5.310	REAL TIME: 5.303
#  [STATUS : 64%]	CPU TIME: 5.180	REAL TIME: 5.174
#  [STATUS : 65%]	CPU TIME: 4.830	REAL TIME: 4.825
#  [STATUS : 66%]	CPU TIME: 5.260	REAL TIME: 5.258
#  [STATUS : 67%]	CPU TIME: 5.000	REAL TIME: 4.997
#  [STATUS : 68%]	CPU TIME: 5.250	REAL TIME: 5.242
#  [STATUS : 69%]	CPU TIME: 5.220	REAL TIME: 5.208
#  [STATUS : 70%]	CPU TIME: 4.520	REAL TIME: 4.523
#  [STATUS : 71%]	CPU TIME: 5.330	REAL TIME: 5.318
#  [STATUS : 72%]	CPU TIME: 5.400	REAL TIME: 5.393
#  [STATUS : 73%]	CPU TIME: 5.760	REAL TIME: 5.762
#  [STATUS : 74%]	CPU TIME: 4.600	REAL TIME: 4.595
#  [STATUS : 75%]	CPU TIME: 5.110	REAL TIME: 5.104
#  [STATUS : 76%]	CPU TIME: 4.730	REAL TIME: 4.724
#  [STATUS : 77%]	CPU TIME: 5.730	REAL TIME: 5.720
#  [STATUS : 78%]	CPU TIME: 5.140	REAL TIME: 5.143
#  [STATUS : 79%]	CPU TIME: 4.810	REAL TIME: 4.800
#  [STATUS : 80%]	CPU TIME: 5.400	REAL TIME: 5.391
#  [STATUS : 81%]	CPU TIME: 5.190	REAL TIME: 5.195
#  [STATUS : 82%]	CPU TIME: 5.450	REAL TIME: 5.439
#  [STATUS : 83%]	CPU TIME: 5.410	REAL TIME: 5.407
#  [STATUS : 84%]	CPU TIME: 6.430	REAL TIME: 6.432
#  [STATUS : 85%]	CPU TIME: 5.510	REAL TIME: 5.508
#  [STATUS : 86%]	CPU TIME: 4.850	REAL TIME: 4.852
#  [STATUS : 87%]	CPU TIME: 6.200	REAL TIME: 6.183
#  [STATUS : 88%]	CPU TIME: 5.030	REAL TIME: 5.037
#  [STATUS : 89%]	CPU TIME: 5.870	REAL TIME: 5.875
#  [STATUS : 90%]	CPU TIME: 4.860	REAL TIME: 4.854
#  [STATUS : 91%]	CPU TIME: 5.430	REAL TIME: 5.425
#  [STATUS : 92%]	CPU TIME: 5.000	REAL TIME: 4.992
#  [STATUS : 93%]	CPU TIME: 5.320	REAL TIME: 5.321
#  [STATUS : 94%]	CPU TIME: 5.350	REAL TIME: 5.356
#  [STATUS : 95%]	CPU TIME: 5.640	REAL TIME: 5.631
#  [STATUS : 96%]	CPU TIME: 5.920	REAL TIME: 5.915
#  [STATUS : 97%]	CPU TIME: 5.820	REAL TIME: 5.825
#  [STATUS : 98%]	CPU TIME: 4.500	REAL TIME: 4.500
#  [STATUS : 99%]	CPU TIME: 5.310	REAL TIME: 5.311
# _________________________________________
# TOTAL NUMBER OF EVENTS BEFORE CUTS:	100000
# NUBER OF EVENTS TO THE INPUT OF KINFIT:	21660
# NUMBER OF EVENTS PASSED e+e- --> KsK+pi- HYPO:	10314
# NUMBER OF EVENTS PASSED e+e- --> KsK-pi+ HYPO:	10475
# NUMBER OF EVENTS PASSED e+e- --> KsK+-pi-+ HYPOS:	20789
# TOTAL CPU TIME :	552.880
# TOTAL REAL TIME :	552.650
# _________________________________________
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/KsKpi_sim_hypo/TrPh_C.so

# %%
fl = TFile.Open(output_path, 'read')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            ylabel='events',
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=4000, h_x=1)
plt.savefig('kf_err_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "kf_err==0", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            ylabel='events',
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=4000, h_x=1)

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "kf_err==0 && numiters < 7", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            ylabel='events',
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=4000, h_x=1)

# %%
19341 / 20789
# Out:
# 0.9303477800760017

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(128,0,200)", "kf_err==0 && numiters>6", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
            fraction=0.47,
             info_coords=(0.3,0.3),
            h_y=200, h_x=50)

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(128,0,200)", "kf_err==0", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
            fraction=0.47,
             info_coords=(0.3,0.3),
            h_y=200, h_x=50)
plt.savefig('kf_chi2_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("in_mks>>in_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(512,0.4,0.6)", "kf_err==0", "goff")
draw_1d_hists([('in_mks', 'before fit'), 
               ('kf_mks', 'after fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
             fraction=0.8,
             info_coords=(0.1, 0.2),
             dh=0.4,
             h_y=200, h_x=0.05)
plt.savefig('kf_mks_simhypo_xkpi.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fl.kf_data.Draw("kf_vtx0[0]>>kf_vtx0_x(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx0[1]>>kf_vtx0_y(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx0[2]>>kf_vtx0_z(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[0]>>kf_vtx1_x(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[1]>>kf_vtx1_y(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[2]>>kf_vtx1_z(256, -10, 10)", "", "goff")
vertices_plot2([['kf_vtx0_x', 'kf_vtx1_x'], 
               ['kf_vtx0_y', 'kf_vtx1_y'],
               ['kf_vtx0_z', 'kf_vtx1_z']],
                info_coords=(0.6, 0.6))

# %%
fl.kf_data.Draw("kf_vtx_dr>>kf_vtx_dr(128, 0, 15)", "", "goff")
draw_1d_hist("kf_vtx_dr", 
             xlabel=r'$\Delta r_{\text{fit}}$ (cm)',
            fraction=0.47,
            info_coords=(0.3, 0.3))
plt.savefig('kf_vtx_dr_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_ks_decay_prod_angle>>kf_angle(32, 0, 3.14159)", "", "goff")
draw_1d_hist("kf_angle", xlabel=r'$\alpha$ (rad)')
plt.savefig('kf_ks_prod_angle_kskpi.eps')

# %%
fl.kf_data.Draw("kf_vtx_drho>>kf_vtx_drho(128, 0, 15)", "", "goff")
draw_1d_hist("kf_vtx_drho", xlabel=r'$\Delta\rho$ (cm)')
plt.savefig('kf_vtx_drho_kskpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_K:kf_p_vtx0_K>>pdedx_K(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_K', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_K_from_vtx0_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_pi:kf_p_vtx0_pi>>pdedx_vtx0_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx0_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx0_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx1_pi[0]:kf_p_vtx1_pi[0]>>pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_dedx_vtx1_pi[1]:kf_p_vtx1_pi[1]>>+pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx1_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx1_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("(kf_vtx_dr-sim_vtx_dr)>>kf_delta_dr(512, -2, 2)", "kf_err==0", "goff")
draw_1d_hist("kf_delta_dr", 
             xlabel=r'$\Delta r_{\text{fit}}-\Delta r_{\text{sim}}$ (cm)',
            fraction=0.8,
            info_coords=(0.55, 0.5))
plt.savefig('kf_sim_vs_kf_dr_1d_xkpi.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0 && kf_chi2<100", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr_chi2_100.eps')

# %%
fl.kf_data.Draw("numiters>>numiters", "kf_err==0 && numiters==6", "goff")
draw_1d_hist("numiters", xlabel=r'number of iterations')

# %%
i2 = 2384 / 20519
i3 = 11030 / 20519
i4 = 3996 / 20519
i5 = 1231 / 20519
i6 = 543 / 20519
print(i2 + i3 + i4 + i5 + i6)
# Out:
# 0.934938349822116

# %%
# fl.Close()
