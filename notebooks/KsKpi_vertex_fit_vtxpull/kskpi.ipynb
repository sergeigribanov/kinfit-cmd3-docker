# %%
from run_kinfit import run_kinfit, build_custom_hypo
from draw_funcs import draw_1d_hist, draw_1d_hists, vertices_plot2, draw_2d_hist, draw_scatter
from ROOT import TFile, TCanvas
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.26/08

# %%
build_custom_hypo('Hypo2PiVertex.cpp')
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/Hypo2PiVertex_cpp.so

# %%
input_path = "/var/kinfit/data/tr_ph_run049912.root"
output_path = "kinfit_kskpi_run049912.root"

# %%
run_kinfit(input_path, output_path=output_path, mfield=1.0)
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# (TFile &) Name: /var/kinfit/data/tr_ph_run049912.root Title:
# (TrPh &) @0x7f67871bb000
#  [STATUS : 01%]	CPU TIME: 6.550	REAL TIME: 6.541
#  [STATUS : 02%]	CPU TIME: 5.960	REAL TIME: 5.957
#  [STATUS : 03%]	CPU TIME: 6.490	REAL TIME: 6.485
#  [STATUS : 04%]	CPU TIME: 5.540	REAL TIME: 5.540
#  [STATUS : 05%]	CPU TIME: 5.800	REAL TIME: 5.798
#  [STATUS : 06%]	CPU TIME: 5.940	REAL TIME: 5.932
#  [STATUS : 07%]	CPU TIME: 5.490	REAL TIME: 5.490
#  [STATUS : 08%]	CPU TIME: 6.310	REAL TIME: 6.306
#  [STATUS : 09%]	CPU TIME: 5.250	REAL TIME: 5.257
#  [STATUS : 10%]	CPU TIME: 6.260	REAL TIME: 6.250
#  [STATUS : 11%]	CPU TIME: 6.680	REAL TIME: 6.711
#  [STATUS : 12%]	CPU TIME: 6.430	REAL TIME: 6.423
#  [STATUS : 13%]	CPU TIME: 6.070	REAL TIME: 6.080
#  [STATUS : 14%]	CPU TIME: 5.940	REAL TIME: 5.931
#  [STATUS : 15%]	CPU TIME: 6.580	REAL TIME: 6.589
#  [STATUS : 16%]	CPU TIME: 6.540	REAL TIME: 6.543
#  [STATUS : 17%]	CPU TIME: 6.390	REAL TIME: 6.390
#  [STATUS : 18%]	CPU TIME: 6.360	REAL TIME: 6.348
#  [STATUS : 19%]	CPU TIME: 6.610	REAL TIME: 6.615
#  [STATUS : 20%]	CPU TIME: 6.750	REAL TIME: 6.758
#  [STATUS : 21%]	CPU TIME: 6.850	REAL TIME: 6.836
#  [STATUS : 22%]	CPU TIME: 5.790	REAL TIME: 5.793
#  [STATUS : 23%]	CPU TIME: 5.940	REAL TIME: 5.938
#  [STATUS : 24%]	CPU TIME: 5.610	REAL TIME: 5.611
#  [STATUS : 25%]	CPU TIME: 5.690	REAL TIME: 5.670
#  [STATUS : 26%]	CPU TIME: 5.590	REAL TIME: 5.594
#  [STATUS : 27%]	CPU TIME: 5.930	REAL TIME: 5.922
#  [STATUS : 28%]	CPU TIME: 5.970	REAL TIME: 5.975
#  [STATUS : 29%]	CPU TIME: 5.840	REAL TIME: 5.833
#  [STATUS : 30%]	CPU TIME: 6.500	REAL TIME: 6.493
#  [STATUS : 31%]	CPU TIME: 5.900	REAL TIME: 5.894
#  [STATUS : 32%]	CPU TIME: 5.350	REAL TIME: 5.343
#  [STATUS : 33%]	CPU TIME: 5.930	REAL TIME: 5.928
#  [STATUS : 34%]	CPU TIME: 6.290	REAL TIME: 6.278
#  [STATUS : 35%]	CPU TIME: 7.100	REAL TIME: 7.109
#  [STATUS : 36%]	CPU TIME: 6.560	REAL TIME: 6.553
#  [STATUS : 37%]	CPU TIME: 6.060	REAL TIME: 6.066
#  [STATUS : 38%]	CPU TIME: 5.950	REAL TIME: 5.946
#  [STATUS : 39%]	CPU TIME: 6.660	REAL TIME: 6.668
#  [STATUS : 40%]	CPU TIME: 5.470	REAL TIME: 5.479
#  [STATUS : 41%]	CPU TIME: 6.080	REAL TIME: 6.088
#  [STATUS : 42%]	CPU TIME: 6.930	REAL TIME: 6.929
#  [STATUS : 43%]	CPU TIME: 6.450	REAL TIME: 6.441
#  [STATUS : 44%]	CPU TIME: 5.500	REAL TIME: 5.521
#  [STATUS : 45%]	CPU TIME: 6.660	REAL TIME: 6.671
#  [STATUS : 46%]	CPU TIME: 5.950	REAL TIME: 5.961
#  [STATUS : 47%]	CPU TIME: 5.740	REAL TIME: 5.734
#  [STATUS : 48%]	CPU TIME: 5.920	REAL TIME: 5.926
#  [STATUS : 49%]	CPU TIME: 6.420	REAL TIME: 6.412
#  [STATUS : 50%]	CPU TIME: 6.400	REAL TIME: 6.389
#  [STATUS : 51%]	CPU TIME: 5.940	REAL TIME: 5.939
#  [STATUS : 52%]	CPU TIME: 5.620	REAL TIME: 5.615
#  [STATUS : 53%]	CPU TIME: 5.480	REAL TIME: 5.481
#  [STATUS : 54%]	CPU TIME: 5.450	REAL TIME: 5.443
#  [STATUS : 55%]	CPU TIME: 5.690	REAL TIME: 5.687
#  [STATUS : 56%]	CPU TIME: 5.520	REAL TIME: 5.507
#  [STATUS : 57%]	CPU TIME: 5.290	REAL TIME: 5.301
#  [STATUS : 58%]	CPU TIME: 5.750	REAL TIME: 5.735
#  [STATUS : 59%]	CPU TIME: 6.410	REAL TIME: 6.412
#  [STATUS : 60%]	CPU TIME: 5.670	REAL TIME: 5.667
#  [STATUS : 61%]	CPU TIME: 5.700	REAL TIME: 5.691
#  [STATUS : 62%]	CPU TIME: 5.620	REAL TIME: 5.622
#  [STATUS : 63%]	CPU TIME: 5.830	REAL TIME: 5.816
#  [STATUS : 64%]	CPU TIME: 6.010	REAL TIME: 6.013
#  [STATUS : 65%]	CPU TIME: 5.190	REAL TIME: 5.179
#  [STATUS : 66%]	CPU TIME: 5.910	REAL TIME: 5.909
#  [STATUS : 67%]	CPU TIME: 5.710	REAL TIME: 5.711
#  [STATUS : 68%]	CPU TIME: 5.770	REAL TIME: 5.761
#  [STATUS : 69%]	CPU TIME: 5.820	REAL TIME: 5.813
#  [STATUS : 70%]	CPU TIME: 4.950	REAL TIME: 4.940
#  [STATUS : 71%]	CPU TIME: 5.770	REAL TIME: 5.771
#  [STATUS : 72%]	CPU TIME: 5.980	REAL TIME: 5.977
#  [STATUS : 73%]	CPU TIME: 6.680	REAL TIME: 6.673
#  [STATUS : 74%]	CPU TIME: 5.050	REAL TIME: 5.045
#  [STATUS : 75%]	CPU TIME: 5.530	REAL TIME: 5.524
#  [STATUS : 76%]	CPU TIME: 5.080	REAL TIME: 5.079
#  [STATUS : 77%]	CPU TIME: 6.280	REAL TIME: 6.271
#  [STATUS : 78%]	CPU TIME: 5.760	REAL TIME: 5.751
#  [STATUS : 79%]	CPU TIME: 5.390	REAL TIME: 5.397
#  [STATUS : 80%]	CPU TIME: 5.820	REAL TIME: 5.815
#  [STATUS : 81%]	CPU TIME: 5.630	REAL TIME: 5.621
#  [STATUS : 82%]	CPU TIME: 5.900	REAL TIME: 5.892
#  [STATUS : 83%]	CPU TIME: 5.610	REAL TIME: 5.607
#  [STATUS : 84%]	CPU TIME: 6.580	REAL TIME: 6.584
#  [STATUS : 85%]	CPU TIME: 5.720	REAL TIME: 5.715
#  [STATUS : 86%]	CPU TIME: 5.290	REAL TIME: 5.286
#  [STATUS : 87%]	CPU TIME: 6.130	REAL TIME: 6.127
#  [STATUS : 88%]	CPU TIME: 5.140	REAL TIME: 5.142
#  [STATUS : 89%]	CPU TIME: 6.030	REAL TIME: 6.037
#  [STATUS : 90%]	CPU TIME: 5.020	REAL TIME: 5.017
#  [STATUS : 91%]	CPU TIME: 6.090	REAL TIME: 6.083
#  [STATUS : 92%]	CPU TIME: 5.380	REAL TIME: 5.397
#  [STATUS : 93%]	CPU TIME: 5.640	REAL TIME: 5.638
#  [STATUS : 94%]	CPU TIME: 5.500	REAL TIME: 5.502
#  [STATUS : 95%]	CPU TIME: 5.610	REAL TIME: 5.604
#  [STATUS : 96%]	CPU TIME: 6.200	REAL TIME: 6.204
#  [STATUS : 97%]	CPU TIME: 6.100	REAL TIME: 6.107
#  [STATUS : 98%]	CPU TIME: 4.830	REAL TIME: 4.825
#  [STATUS : 99%]	CPU TIME: 5.570	REAL TIME: 5.582
# _________________________________________
# TOTAL NUMBER OF EVENTS BEFORE CUTS:	100000
# NUBER OF EVENTS TO THE INPUT OF KINFIT:	21660
# NUMBER OF EVENTS PASSED e+e- --> KsK+pi- HYPO:	10314
# NUMBER OF EVENTS PASSED e+e- --> KsK-pi+ HYPO:	10475
# NUMBER OF EVENTS PASSED e+e- --> KsK+-pi-+ HYPOS:	20789
# TOTAL CPU TIME :	591.190
# TOTAL REAL TIME :	591.035
# _________________________________________
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh_C.so
# In file included from /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh_C_ACLiC_dict.cxx:41:
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C: In member function ‘virtual void TrPh::Loop(const std::string&, double)’:
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:270:10: warning: ‘v_sigma_z_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   270 |   double v_sigma_z_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:269:10: warning: ‘v_sigma_y_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   269 |   double v_sigma_y_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:268:10: warning: ‘v_sigma_x_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   268 |   double v_sigma_x_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:267:10: warning: ‘v_sigma_z_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   267 |   double v_sigma_z_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:265:10: warning: ‘v_sigma_z_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   265 |   double v_sigma_z_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:264:10: warning: ‘v_sigma_y_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   264 |   double v_sigma_y_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:263:10: warning: ‘v_sigma_x_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   263 |   double v_sigma_x_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:262:10: warning: ‘v_sigma_z_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   262 |   double v_sigma_z_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# In file included from /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh_C_ACLiC_dict.cxx:41:
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C: In member function ‘virtual void TrPh::Loop(const std::string&, double)’:
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:270:10: warning: ‘v_sigma_z_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   270 |   double v_sigma_z_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:269:10: warning: ‘v_sigma_y_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   269 |   double v_sigma_y_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:268:10: warning: ‘v_sigma_x_vtx1_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   268 |   double v_sigma_x_vtx1_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:267:10: warning: ‘v_sigma_z_vtx0_minus’ may be used uninitialized [-Wmaybe-uninitialized]
#   267 |   double v_sigma_z_vtx0_minus;
#       |          ^~~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:265:10: warning: ‘v_sigma_z_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   265 |   double v_sigma_z_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:264:10: warning: ‘v_sigma_y_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   264 |   double v_sigma_y_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:263:10: warning: ‘v_sigma_x_vtx1_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   263 |   double v_sigma_x_vtx1_plus;
#       |          ^~~~~~~~~~~~~~~~~~~
# /home/hep/workdir/notebooks/KsKpi_vertex_fit_vtxpull/TrPh.C:262:10: warning: ‘v_sigma_z_vtx0_plus’ may be used uninitialized [-Wmaybe-uninitialized]
#   262 |   double v_sigma_z_vtx0_plus;
#       |          ^~~~~~~~~~~~~~~~~~~

# %%
fl = TFile.Open(output_path, 'read')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "", "goff")
draw_1d_hist("kf_err_kskpi", xlabel='error code', 
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=5000, h_x=1)
plt.savefig('kf_err_xkpi.eps')

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(128,0,200)", "kf_err==0", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
             fraction=0.47,
             info_coords=(0.0, -1.0),
            h_y=200, h_x=50)
plt.savefig('kf_chi2_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("in_mks>>in_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(512,0.4,0.6)", "kf_err==0", "goff")
draw_1d_hists([('kf_vtx_mks', 'vertex fit'), ('kf_mks', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
              fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=200, h_x=0.05)
plt.savefig('kf_mks_xkpi.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fl.kf_data.Draw("kf_vtx0[0]>>kf_vtx0_x(128, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx0[1]>>kf_vtx0_y(128, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx0[2]>>kf_vtx0_z(128, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[0]>>kf_vtx1_x(128, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[1]>>kf_vtx1_y(128, -10, 10)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx1[2]>>kf_vtx1_z(128, -10, 10)", "kf_err==0", "goff")
vertices_plot2([['kf_vtx0_x', 'kf_vtx1_x'], 
               ['kf_vtx0_y', 'kf_vtx1_y'],
               ['kf_vtx0_z', 'kf_vtx1_z']],
               fraction=0.8, 
               hspace=0.4, 
               wspace=0.6,
              hs_y=[[6000, 800], [6000, 800], [150, 150]],
              hs_x=[[5, 5], [5, 5], [5, 5]])
plt.savefig('kf_vtx_xkpi.eps')

# %%
cnv0 = TCanvas()
fl.kf_data.Draw("sigma_x_vtx1", "kf_err==0 && sigma_x_vtx1<0.25")
cnv0.Draw()

# %%
fl.kf_data.Draw("(kf_vtx0[2]-sim_ee_vtx[2])/sigma_z_vtx0 >>kf_vtx_dz1(128, -20, 20)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dz1", 
             xlabel=r'$\Delta z_{1}/\sqrt{\text{var}(z^{\text{fit}}_1)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
           h_y=100, h_x=10.0)
plt.savefig('kskpi_vtx0_dz_pull.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx1[0]-sim_ks_vtx[0])/sigma_x_vtx1 >>kf_vtx_dx2(128, -10.0, 10.0)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dx2", 
             xlabel=r'$\Delta x_{2} / \sqrt{\text{var}(x^{\text{fit}}_2)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=200, h_x=5.0)
plt.savefig('kskpi_vtx1_dx_pull.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx1[1]-sim_ks_vtx[1])/sigma_y_vtx1>>kf_vtx_dy2(128, -10.0, 10.0)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dy2", 
             xlabel=r'$\Delta y_{2} / \sqrt{\text{var}(y^{\text{fit}}_2)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=200, h_x=5.0)
plt.savefig('kskpi_vtx1_dy_pull.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("(kf_vtx1[2]-sim_ks_vtx[2])/sigma_z_vtx1>>kf_vtx_dz2(128, -20., 20.)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dz2", 
             xlabel=r'$\Delta z_{2} / \sqrt{\text{var}(z^{\text{fit}}_2)}$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=100, h_x=10.0)
plt.savefig('kskpi_vtx1_dz_pull.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx_dr>>kf_vtx_dr(128, 0, 15)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dr", 
             xlabel=r'$\Delta r_{\text{fit}}$ (cm)',
             ylabel='events',
             fraction=0.47, 
            info_coords=(0.3, 0.3),
            h_y=300, h_x=5)
plt.savefig('kf_vtx_dr_xkpi.eps')

# %%
fl.kf_data.Draw("kf_ks_decay_prod_angle>>kf_angle(32, 0, 3.14159)", "kf_err==0", "goff")
draw_1d_hist("kf_angle", xlabel=r'$\alpha$ (rad)')
plt.savefig('kf_ks_prod_angle_xkpi.eps')

# %%
fl.kf_data.Draw("kf_vtx_drho>>kf_vtx_drho(128, 0, 15)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_drho", xlabel=r'$\Delta\rho$ (cm)')
plt.savefig('kf_vtx_drho_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_K:kf_p_vtx0_K>>pdedx_K(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_K', xlabel=r'$P$ (GeV/c)', ylabel=r'$dE/dx\text{ (AU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_K_from_vtx0_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_pi:kf_p_vtx0_pi>>pdedx_vtx0_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx0_pi', xlabel=r'$P$ (GeV/c)', ylabel=r'$dE/dx\text{ (AU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx0_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx1_pi[0]:kf_p_vtx1_pi[0]>>pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_dedx_vtx1_pi[1]:kf_p_vtx1_pi[1]>>+pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx1_pi', xlabel=r'$P$ (GeV/c)', ylabel=r'$dE/dx\text{ (AU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx1_xkpi.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', 
             xlabel=r'$\Delta r_{\text{sim}}$ (cm)', 
             ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)', 
             fraction=0.47)
plt.savefig('kf_sim_vs_kf_dr_xkpi.eps')

# %%
fl.kf_data.Draw("sim_vtx_dr:kf_vtx_dr>>sim_kf_vtx_dr(64, 0, 15., 64, 0, 15.)", "kf_err==0", "goff")
draw_2d_hist('sim_kf_vtx_dr', 
            xlabel=r'$\Delta r_{\text{sim}}$ (cm)', 
            ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)',
            fraction=0.47)
plt.savefig('kf_sim_vs_kf_dr_colormap_xkpi.eps')

# %%
fl.kf_data.Draw("(kf_vtx_dr-sim_vtx_dr)>>kf_delta_dr(512, -2, 2)", "kf_err==0", "goff")
draw_1d_hist("kf_delta_dr", 
             xlabel=r'$\Delta r_{\text{fit}}-\Delta r_{\text{sim}}$ (cm)',
             ylabel='events',
            fraction=0.8,
            info_coords=(0.55, 0.5),
            h_y=300, h_x=1)
plt.savefig('kf_sim_vs_kf_dr_1d_xkpi.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0 && kf_chi2<100", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', 
             xlabel=r'$\Delta r_{\text{sim}}$ (cm)', 
             ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)',
            fraction=0.47)
plt.savefig('kf_sim_vs_kf_dr_chi2_100_xkpi.eps')

# %%
fl.kf_data.Draw("sim_vtx_dr:kf_vtx_dr>>sim_kf_vtx_dr_100(64, 0, 15., 64, 0, 15.)", 
                "kf_err==0 && kf_chi2<100", "goff")
draw_2d_hist('sim_kf_vtx_dr_100', 
            xlabel=r'$\Delta r_{\text{sim}}$ (cm)', 
            ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)',
            fraction=0.47)
plt.savefig('kf_sim_vs_kf_dr_chi2_100_colormap_xkpi.eps')

# %%
fl.kf_data.Draw("(kf_vtx_dr-sim_vtx_dr)>>kf_delta_dr_100(256, -5, 5)", 
                "kf_err==0 && kf_chi2<100", "goff")
draw_1d_hist("kf_delta_dr_100", xlabel=r'$\Delta r$ (cm)',
            fraction=0.47)
plt.savefig('kf_sim_vs_kf_dr_chi2_100_1d_xkpi.eps')

# %%
fl.kf_data.Draw("kf_hypo>>kf_hypo_sim0", 
                "kf_err==0 && sim_hypo==0", "goff")
draw_1d_hist("kf_hypo_sim0", xlabel=r'',
            fraction=0.47)
plt.savefig('kf_hypo_kskplpimi_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_hypo>>kf_hypo_sim1", 
                "kf_err==0 && sim_hypo==1", "goff")
draw_1d_hist("kf_hypo_sim1", xlabel=r'',
            fraction=0.47)
plt.savefig('kf_hypo_kskmipipl_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks(128,0.4,0.6)", "kf_err==0 && kf_hypo==1 && sim_hypo==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>+kf_vtx_mks", "kf_err==0 && kf_hypo==0 && sim_hypo==1", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(128,0.4,0.6)", "kf_err==0 && kf_hypo==1 && sim_hypo==0", "goff")
fl.kf_data.Draw("kf_mks>>+kf_mks", "kf_err==0 && kf_hypo==0 && sim_hypo==1", "goff")
draw_1d_hists([('kf_vtx_mks', 'vertex fit'), ('kf_mks', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=100, h_x=0.05)
plt.savefig('kf_mks_wrong_xkpi.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks1(128,0.4,0.6)", "kf_err==0 && kf_hypo==0 && sim_hypo==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>+kf_vtx_mks1", "kf_err==0 && kf_hypo==1 && sim_hypo==1", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks1(128,0.4,0.6)", "kf_err==0 && kf_hypo==0 && sim_hypo==0", "goff")
fl.kf_data.Draw("kf_mks>>+kf_mks1", "kf_err==0 && kf_hypo==1 && sim_hypo==1", "goff")
draw_1d_hists([('kf_vtx_mks1', 'vertex fit'), ('kf_mks1', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
             fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=500, h_x=0.05)
plt.savefig('kf_mks_good_xkpi.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# fl.Close()
