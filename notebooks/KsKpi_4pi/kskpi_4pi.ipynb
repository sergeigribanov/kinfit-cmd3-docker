# %%
from run_kinfit import run_kinfit
from draw_funcs import draw_1d_hist, draw_1d_hists, vertices_plot2, draw_2d_hist, draw_scatter
from ROOT import TFile
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.26/08

# %%
input_path = "/var/kinfit/data/tr_ph_run059700.root"
output_path = "kinfit_run059700.root"

# %%
run_kinfit(input_path, output_path=output_path, mfield=1.0)
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# (TFile &) Name: /var/kinfit/data/tr_ph_run059700.root Title:
# (TrPh &) @0x7f329fdcb000
#  [STATUS : 01%]	CPU TIME: 11.940	REAL TIME: 11.981
#  [STATUS : 02%]	CPU TIME: 12.370	REAL TIME: 12.366
#  [STATUS : 03%]	CPU TIME: 11.620	REAL TIME: 11.625
#  [STATUS : 04%]	CPU TIME: 10.880	REAL TIME: 10.909
#  [STATUS : 05%]	CPU TIME: 11.670	REAL TIME: 11.675
#  [STATUS : 06%]	CPU TIME: 11.840	REAL TIME: 11.860
#  [STATUS : 07%]	CPU TIME: 12.010	REAL TIME: 12.013
#  [STATUS : 08%]	CPU TIME: 12.450	REAL TIME: 12.465
#  [STATUS : 09%]	CPU TIME: 12.120	REAL TIME: 12.130
#  [STATUS : 10%]	CPU TIME: 11.740	REAL TIME: 11.748
#  [STATUS : 11%]	CPU TIME: 12.490	REAL TIME: 12.526
#  [STATUS : 12%]	CPU TIME: 12.060	REAL TIME: 12.072
#  [STATUS : 13%]	CPU TIME: 12.260	REAL TIME: 12.254
#  [STATUS : 14%]	CPU TIME: 11.340	REAL TIME: 11.367
#  [STATUS : 15%]	CPU TIME: 11.640	REAL TIME: 11.643
#  [STATUS : 16%]	CPU TIME: 12.270	REAL TIME: 12.260
#  [STATUS : 17%]	CPU TIME: 12.440	REAL TIME: 12.444
#  [STATUS : 18%]	CPU TIME: 11.400	REAL TIME: 11.388
#  [STATUS : 19%]	CPU TIME: 11.010	REAL TIME: 11.002
#  [STATUS : 20%]	CPU TIME: 11.380	REAL TIME: 11.374
#  [STATUS : 21%]	CPU TIME: 10.910	REAL TIME: 10.887
#  [STATUS : 22%]	CPU TIME: 11.400	REAL TIME: 11.394
#  [STATUS : 23%]	CPU TIME: 11.120	REAL TIME: 11.123
#  [STATUS : 24%]	CPU TIME: 11.320	REAL TIME: 11.317
#  [STATUS : 25%]	CPU TIME: 10.940	REAL TIME: 10.926
#  [STATUS : 26%]	CPU TIME: 11.730	REAL TIME: 11.721
#  [STATUS : 27%]	CPU TIME: 10.600	REAL TIME: 10.593
#  [STATUS : 28%]	CPU TIME: 10.990	REAL TIME: 10.980
#  [STATUS : 29%]	CPU TIME: 11.000	REAL TIME: 10.992
#  [STATUS : 30%]	CPU TIME: 12.570	REAL TIME: 12.629
#  [STATUS : 31%]	CPU TIME: 11.950	REAL TIME: 11.945
#  [STATUS : 32%]	CPU TIME: 11.650	REAL TIME: 11.657
#  [STATUS : 33%]	CPU TIME: 11.240	REAL TIME: 11.236
#  [STATUS : 34%]	CPU TIME: 11.200	REAL TIME: 11.190
#  [STATUS : 35%]	CPU TIME: 10.840	REAL TIME: 10.831
#  [STATUS : 36%]	CPU TIME: 11.110	REAL TIME: 11.100
#  [STATUS : 37%]	CPU TIME: 11.510	REAL TIME: 11.518
#  [STATUS : 38%]	CPU TIME: 10.260	REAL TIME: 10.260
#  [STATUS : 39%]	CPU TIME: 10.820	REAL TIME: 10.815
#  [STATUS : 40%]	CPU TIME: 10.850	REAL TIME: 10.827
#  [STATUS : 41%]	CPU TIME: 10.620	REAL TIME: 10.614
#  [STATUS : 42%]	CPU TIME: 10.430	REAL TIME: 10.419
#  [STATUS : 43%]	CPU TIME: 11.070	REAL TIME: 11.066
#  [STATUS : 44%]	CPU TIME: 11.670	REAL TIME: 11.662
#  [STATUS : 45%]	CPU TIME: 12.760	REAL TIME: 12.782
#  [STATUS : 46%]	CPU TIME: 12.030	REAL TIME: 12.048
#  [STATUS : 47%]	CPU TIME: 12.630	REAL TIME: 12.627
#  [STATUS : 48%]	CPU TIME: 11.210	REAL TIME: 11.209
#  [STATUS : 49%]	CPU TIME: 10.820	REAL TIME: 10.813
#  [STATUS : 50%]	CPU TIME: 12.510	REAL TIME: 12.502
#  [STATUS : 51%]	CPU TIME: 13.520	REAL TIME: 13.534
#  [STATUS : 52%]	CPU TIME: 12.650	REAL TIME: 12.684
#  [STATUS : 53%]	CPU TIME: 12.020	REAL TIME: 12.011
#  [STATUS : 54%]	CPU TIME: 11.430	REAL TIME: 11.434
#  [STATUS : 55%]	CPU TIME: 11.110	REAL TIME: 11.132
#  [STATUS : 56%]	CPU TIME: 10.970	REAL TIME: 10.958
#  [STATUS : 57%]	CPU TIME: 10.890	REAL TIME: 10.891
#  [STATUS : 58%]	CPU TIME: 11.720	REAL TIME: 11.710
#  [STATUS : 59%]	CPU TIME: 11.430	REAL TIME: 11.452
#  [STATUS : 60%]	CPU TIME: 11.780	REAL TIME: 11.776
#  [STATUS : 61%]	CPU TIME: 11.820	REAL TIME: 11.819
#  [STATUS : 62%]	CPU TIME: 12.470	REAL TIME: 12.472
#  [STATUS : 63%]	CPU TIME: 11.240	REAL TIME: 11.248
#  [STATUS : 64%]	CPU TIME: 12.270	REAL TIME: 12.274
#  [STATUS : 65%]	CPU TIME: 12.680	REAL TIME: 12.681
#  [STATUS : 66%]	CPU TIME: 11.630	REAL TIME: 11.621
#  [STATUS : 67%]	CPU TIME: 10.880	REAL TIME: 10.885
#  [STATUS : 68%]	CPU TIME: 11.370	REAL TIME: 11.368
#  [STATUS : 69%]	CPU TIME: 11.060	REAL TIME: 11.042
#  [STATUS : 70%]	CPU TIME: 11.050	REAL TIME: 11.040
#  [STATUS : 71%]	CPU TIME: 11.430	REAL TIME: 11.424
#  [STATUS : 72%]	CPU TIME: 11.650	REAL TIME: 11.648
#  [STATUS : 73%]	CPU TIME: 10.850	REAL TIME: 10.833
#  [STATUS : 74%]	CPU TIME: 10.770	REAL TIME: 10.775
#  [STATUS : 75%]	CPU TIME: 10.810	REAL TIME: 10.806
#  [STATUS : 76%]	CPU TIME: 10.750	REAL TIME: 10.732
#  [STATUS : 77%]	CPU TIME: 10.980	REAL TIME: 10.968
#  [STATUS : 78%]	CPU TIME: 11.270	REAL TIME: 11.273
#  [STATUS : 79%]	CPU TIME: 11.580	REAL TIME: 11.580
#  [STATUS : 80%]	CPU TIME: 11.030	REAL TIME: 11.017
#  [STATUS : 81%]	CPU TIME: 11.700	REAL TIME: 11.689
#  [STATUS : 82%]	CPU TIME: 11.900	REAL TIME: 11.921
#  [STATUS : 83%]	CPU TIME: 10.700	REAL TIME: 10.693
#  [STATUS : 84%]	CPU TIME: 10.770	REAL TIME: 10.763
#  [STATUS : 85%]	CPU TIME: 11.020	REAL TIME: 11.026
#  [STATUS : 86%]	CPU TIME: 12.640	REAL TIME: 12.635
#  [STATUS : 87%]	CPU TIME: 10.010	REAL TIME: 10.000
#  [STATUS : 88%]	CPU TIME: 11.230	REAL TIME: 11.245
#  [STATUS : 89%]	CPU TIME: 12.120	REAL TIME: 12.133
#  [STATUS : 90%]	CPU TIME: 11.560	REAL TIME: 11.579
#  [STATUS : 91%]	CPU TIME: 10.880	REAL TIME: 10.867
#  [STATUS : 92%]	CPU TIME: 10.560	REAL TIME: 10.557
#  [STATUS : 93%]	CPU TIME: 12.230	REAL TIME: 12.222
#  [STATUS : 94%]	CPU TIME: 12.670	REAL TIME: 12.688
#  [STATUS : 95%]	CPU TIME: 11.070	REAL TIME: 11.072
#  [STATUS : 96%]	CPU TIME: 11.220	REAL TIME: 11.210
#  [STATUS : 97%]	CPU TIME: 11.670	REAL TIME: 11.656
#  [STATUS : 98%]	CPU TIME: 12.170	REAL TIME: 12.160
#  [STATUS : 99%]	CPU TIME: 11.310	REAL TIME: 11.303
# _________________________________________
# TOTAL NUMBER OF EVENTS BEFORE CUTS:	100000
# NUBER OF EVENTS TO THE INPUT OF KINFIT:	45199
# NUMBER OF EVENTS PASSED e+e- --> KsK+pi- HYPO:	22393
# NUMBER OF EVENTS PASSED e+e- --> KsK-pi+ HYPO:	22383
# NUMBER OF EVENTS PASSED e+e- --> KsK+-pi-+ HYPOS:	44776
# TOTAL CPU TIME :	1151.080
# TOTAL REAL TIME :	1151.190
# _________________________________________
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/KsKpi_4pi/TrPh_C.so

# %%
fl = TFile.Open(output_path, 'read')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            fraction=0.47,
            info_coords=(0.3, 0.3))
plt.savefig('kf_err_4pi_xkpi.eps')

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(64,0,600)", "kf_err==0", "goff")
draw_1d_hist("kf_chi2_kskpi", 
             xlabel=r'$\chi^2$',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=400, h_x=150)
plt.savefig('kf_chi2_4pi_xkpi.eps',  bbox_inches='tight')

# %%
fl.kf_data.Draw("in_mks>>in_mks(512,0.2,0.8)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(512,0.2,0.8)", "kf_err==0", "goff")
draw_1d_hists([('in_mks', 'before kinematic fit'), ('kf_mks', 'after kinematic fit')], xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)')

# %%
fl.kf_data.Draw("kf_vtx0[0]>>kf_vtx0_x(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx0[1]>>kf_vtx0_y(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx0[2]>>kf_vtx0_z(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[0]>>kf_vtx1_x(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[1]>>kf_vtx1_y(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[2]>>kf_vtx1_z(256, -10, 10)", "", "goff")
vertices_plot2([['kf_vtx0_x', 'kf_vtx1_x'], 
               ['kf_vtx0_y', 'kf_vtx1_y'],
               ['kf_vtx0_z', 'kf_vtx1_z']],
                info_coords=(0.6, 0.6))

# %%
fl.kf_data.Draw("kf_vtx_dr>>kf_vtx_dr(64, 0, 1)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dr", 
             xlabel=r'$\Delta r_{\text{fit}}$ (cm)',
             ylabel='events',
            fraction=0.47,
            info_coords=(0.0, -1.0),
            h_y=800, h_x=0.25)
plt.savefig('kf_vtx_dr_4pi_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("kf_ks_decay_prod_angle>>kf_angle(32, 0, 3.14159)", "", "goff")
draw_1d_hist("kf_angle", xlabel=r'$\alpha$ (rad)')
plt.savefig('kf_ks_prod_angle_kskpi.eps')

# %%
fl.kf_data.Draw("kf_vtx_drho>>kf_vtx_drho(128, 0, 1)", "", "goff")
draw_1d_hist("kf_vtx_drho", xlabel=r'$\Delta\rho$ (cm)')
plt.savefig('kf_vtx_drho_kskpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_K:kf_p_vtx0_K>>pdedx_K(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_K', xlabel=r'$P$ (GeV/c)', ylabel=r'$dE/dx$')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_pi:kf_p_vtx0_pi>>pdedx_vtx0_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx0_pi', xlabel=r'$P$ (GeV/c)', ylabel=r'$dE/dx$')

# %%
fl.kf_data.Draw("kf_dedx_vtx1_pi[0]:kf_p_vtx1_pi[0]>>pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_dedx_vtx1_pi[1]:kf_p_vtx1_pi[1]>>+pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx1_pi', xlabel=r'$P$ (GeV/c)', ylabel=r'$dE/dx$')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0 && kf_chi2<100", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr_chi2_100.eps')

# %%
# fl.Close()
