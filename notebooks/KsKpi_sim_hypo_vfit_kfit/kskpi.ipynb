# %%
from run_kinfit import run_kinfit, build_custom_hypo
from draw_funcs import draw_1d_hist, draw_1d_hists, vertices_plot2, draw_2d_hist, draw_scatter
from ROOT import TFile, TCanvas
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.26/08

# %%
# build_custom_hypo('Hypo2PiVertex.cpp')
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/KsKpi_sim_hypo_vfit_kfit/Hypo2PiVertex_cpp.so

# %%
input_path = "/var/kinfit/data/tr_ph_run049912.root"
output_path = "kinfit_kskpi_run049912.root"

# %%
# run_kinfit(input_path, output_path=output_path, mfield=1.0)
# 21281
# KsK+pi- 10174
# KsK-pi+ 10345
# KsKpi 20519
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# (int) 0
# (TFile &) Name: /var/kinfit/data/tr_ph_run049912.root Title:
# (TrPh &) @0x7f908eb24000
#  [STATUS : 01%]	CPU TIME: 15.470	REAL TIME: 15.460
#  [STATUS : 02%]	CPU TIME: 14.040	REAL TIME: 14.030
#  [STATUS : 03%]	CPU TIME: 15.020	REAL TIME: 15.001
#  [STATUS : 04%]	CPU TIME: 12.490	REAL TIME: 12.478
#  [STATUS : 05%]	CPU TIME: 13.600	REAL TIME: 13.591
#  [STATUS : 06%]	CPU TIME: 13.860	REAL TIME: 13.846
#  [STATUS : 07%]	CPU TIME: 12.990	REAL TIME: 12.983
#  [STATUS : 08%]	CPU TIME: 14.380	REAL TIME: 14.367
#  [STATUS : 09%]	CPU TIME: 12.880	REAL TIME: 12.857
#  [STATUS : 10%]	CPU TIME: 14.560	REAL TIME: 14.558
#  [STATUS : 11%]	CPU TIME: 14.550	REAL TIME: 14.532
#  [STATUS : 12%]	CPU TIME: 14.780	REAL TIME: 14.777
#  [STATUS : 13%]	CPU TIME: 14.190	REAL TIME: 14.178
#  [STATUS : 14%]	CPU TIME: 13.970	REAL TIME: 13.958
#  [STATUS : 15%]	CPU TIME: 14.390	REAL TIME: 14.388
#  [STATUS : 16%]	CPU TIME: 13.250	REAL TIME: 13.246
#  [STATUS : 17%]	CPU TIME: 15.980	REAL TIME: 15.952
#  [STATUS : 18%]	CPU TIME: 16.010	REAL TIME: 16.005
#  [STATUS : 19%]	CPU TIME: 16.020	REAL TIME: 16.002
#  [STATUS : 20%]	CPU TIME: 13.290	REAL TIME: 13.279
#  [STATUS : 21%]	CPU TIME: 16.440	REAL TIME: 16.427
#  [STATUS : 22%]	CPU TIME: 14.280	REAL TIME: 14.261
#  [STATUS : 23%]	CPU TIME: 14.720	REAL TIME: 14.711
#  [STATUS : 24%]	CPU TIME: 14.210	REAL TIME: 14.200
#  [STATUS : 25%]	CPU TIME: 13.610	REAL TIME: 13.599
#  [STATUS : 26%]	CPU TIME: 13.430	REAL TIME: 13.413
#  [STATUS : 27%]	CPU TIME: 14.820	REAL TIME: 14.822
#  [STATUS : 28%]	CPU TIME: 13.850	REAL TIME: 13.834
#  [STATUS : 29%]	CPU TIME: 14.450	REAL TIME: 14.447
#  [STATUS : 30%]	CPU TIME: 16.660	REAL TIME: 16.657
#  [STATUS : 31%]	CPU TIME: 15.680	REAL TIME: 15.682
#  [STATUS : 32%]	CPU TIME: 14.420	REAL TIME: 14.410
#  [STATUS : 33%]	CPU TIME: 15.970	REAL TIME: 15.961
#  [STATUS : 34%]	CPU TIME: 16.770	REAL TIME: 16.756
#  [STATUS : 35%]	CPU TIME: 15.270	REAL TIME: 15.272
#  [STATUS : 36%]	CPU TIME: 14.360	REAL TIME: 14.337
#  [STATUS : 37%]	CPU TIME: 14.840	REAL TIME: 14.833
#  [STATUS : 38%]	CPU TIME: 13.470	REAL TIME: 13.459
#  [STATUS : 39%]	CPU TIME: 14.770	REAL TIME: 14.759
#  [STATUS : 40%]	CPU TIME: 12.850	REAL TIME: 12.843
#  [STATUS : 41%]	CPU TIME: 14.300	REAL TIME: 14.288
#  [STATUS : 42%]	CPU TIME: 15.650	REAL TIME: 15.630
#  [STATUS : 43%]	CPU TIME: 14.850	REAL TIME: 14.839
#  [STATUS : 44%]	CPU TIME: 13.930	REAL TIME: 13.932
#  [STATUS : 45%]	CPU TIME: 15.510	REAL TIME: 15.522
#  [STATUS : 46%]	CPU TIME: 14.960	REAL TIME: 14.963
#  [STATUS : 47%]	CPU TIME: 14.470	REAL TIME: 14.458
#  [STATUS : 48%]	CPU TIME: 15.610	REAL TIME: 15.598
#  [STATUS : 49%]	CPU TIME: 17.000	REAL TIME: 17.008
#  [STATUS : 50%]	CPU TIME: 15.960	REAL TIME: 15.943
#  [STATUS : 51%]	CPU TIME: 15.370	REAL TIME: 15.372
#  [STATUS : 52%]	CPU TIME: 15.600	REAL TIME: 15.602
#  [STATUS : 53%]	CPU TIME: 14.670	REAL TIME: 14.673
#  [STATUS : 54%]	CPU TIME: 14.580	REAL TIME: 14.571
#  [STATUS : 55%]	CPU TIME: 15.180	REAL TIME: 15.184
#  [STATUS : 56%]	CPU TIME: 14.230	REAL TIME: 14.212
#  [STATUS : 57%]	CPU TIME: 12.600	REAL TIME: 12.588
#  [STATUS : 58%]	CPU TIME: 14.200	REAL TIME: 14.193
#  [STATUS : 59%]	CPU TIME: 14.800	REAL TIME: 14.788
#  [STATUS : 60%]	CPU TIME: 13.550	REAL TIME: 13.540
#  [STATUS : 61%]	CPU TIME: 13.610	REAL TIME: 13.592
#  [STATUS : 62%]	CPU TIME: 13.570	REAL TIME: 13.561
#  [STATUS : 63%]	CPU TIME: 14.310	REAL TIME: 14.291
#  [STATUS : 64%]	CPU TIME: 14.290	REAL TIME: 14.277
#  [STATUS : 65%]	CPU TIME: 13.320	REAL TIME: 13.314
#  [STATUS : 66%]	CPU TIME: 14.260	REAL TIME: 14.251
#  [STATUS : 67%]	CPU TIME: 14.070	REAL TIME: 14.057
#  [STATUS : 68%]	CPU TIME: 14.320	REAL TIME: 14.309
#  [STATUS : 69%]	CPU TIME: 15.230	REAL TIME: 15.223
#  [STATUS : 70%]	CPU TIME: 12.580	REAL TIME: 12.570
#  [STATUS : 71%]	CPU TIME: 14.640	REAL TIME: 14.632
#  [STATUS : 72%]	CPU TIME: 14.400	REAL TIME: 14.397
#  [STATUS : 73%]	CPU TIME: 15.000	REAL TIME: 14.975
#  [STATUS : 74%]	CPU TIME: 13.020	REAL TIME: 13.022
#  [STATUS : 75%]	CPU TIME: 14.360	REAL TIME: 14.343
#  [STATUS : 76%]	CPU TIME: 13.020	REAL TIME: 13.008
#  [STATUS : 77%]	CPU TIME: 15.380	REAL TIME: 15.363
#  [STATUS : 78%]	CPU TIME: 13.780	REAL TIME: 13.765
#  [STATUS : 79%]	CPU TIME: 13.380	REAL TIME: 13.376
#  [STATUS : 80%]	CPU TIME: 14.910	REAL TIME: 14.892
#  [STATUS : 81%]	CPU TIME: 14.570	REAL TIME: 14.568
#  [STATUS : 82%]	CPU TIME: 15.060	REAL TIME: 15.043
#  [STATUS : 83%]	CPU TIME: 13.770	REAL TIME: 13.758
#  [STATUS : 84%]	CPU TIME: 16.570	REAL TIME: 16.562
#  [STATUS : 85%]	CPU TIME: 14.100	REAL TIME: 14.088
#  [STATUS : 86%]	CPU TIME: 13.180	REAL TIME: 13.168
#  [STATUS : 87%]	CPU TIME: 15.220	REAL TIME: 15.214
#  [STATUS : 88%]	CPU TIME: 12.880	REAL TIME: 12.861
#  [STATUS : 89%]	CPU TIME: 14.940	REAL TIME: 14.927
#  [STATUS : 90%]	CPU TIME: 12.860	REAL TIME: 12.840
#  [STATUS : 91%]	CPU TIME: 14.210	REAL TIME: 14.199
#  [STATUS : 92%]	CPU TIME: 13.900	REAL TIME: 13.886
#  [STATUS : 93%]	CPU TIME: 14.140	REAL TIME: 14.131
#  [STATUS : 94%]	CPU TIME: 13.810	REAL TIME: 13.800
#  [STATUS : 95%]	CPU TIME: 14.530	REAL TIME: 14.513
#  [STATUS : 96%]	CPU TIME: 16.000	REAL TIME: 15.995
#  [STATUS : 97%]	CPU TIME: 15.090	REAL TIME: 15.085
#  [STATUS : 98%]	CPU TIME: 12.460	REAL TIME: 12.445
#  [STATUS : 99%]	CPU TIME: 14.080	REAL TIME: 14.073
# _________________________________________
# TOTAL NUMBER OF EVENTS BEFORE CUTS:	100000
# NUBER OF EVENTS TO THE INPUT OF KINFIT:	21660
# NUMBER OF EVENTS PASSED e+e- --> KsK+pi- HYPO:	10314
# NUMBER OF EVENTS PASSED e+e- --> KsK-pi+ HYPO:	10475
# NUMBER OF EVENTS PASSED e+e- --> KsK+-pi-+ HYPOS:	20789
# TOTAL CPU TIME :	1444.780
# TOTAL REAL TIME :	1443.792
# _________________________________________
# Info in <TUnixSystem::ACLiC>: creating shared library /home/hep/workdir/notebooks/KsKpi_sim_hypo_vfit_kfit/TrPh_C.so

# %%
fl = TFile.Open(output_path, 'read')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            ylabel='events',
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=4000, h_x=1)
plt.savefig('kf_err_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "kf_err==0", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            ylabel='events',
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=4000, h_x=1)

# %%
fl.kf_data.Draw("kf_err>>kf_err_kskpi(3,0,3)", "kf_err==0 && numiters>6", "goff")
draw_1d_hist("kf_err_kskpi", 
             xlabel='error code',
            ylabel='events',
             fraction=0.47,
             info_coords=(0.3, 0.3),
            h_y=4000, h_x=1)

# %%
1448 / 20789
# Out:
# 0.06965221992399827

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(64,0,200)", "kf_err==0 && numiters>6", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
            fraction=0.47,
             info_coords=(0.3,0.3),
            h_y=10, h_x=50)
plt.savefig('kf_chi2_simhypo_xkpi_numiters_grater6.eps')

# %%
cnv = TCanvas()
fl.kf_data.Draw("q_val", "kf_err==0 && q_val>-100 && q_val<100 && numiters>6")
cnv.Draw()

# %%
fl.kf_data.Draw("kf_chi2>>kf_chi2_kskpi(128,0,200)", "kf_err==0", "goff")
draw_1d_hist("kf_chi2_kskpi", xlabel=r'$\chi^2$',
             ylabel='events',
            fraction=0.47,
             info_coords=(0.0,-1.0),
            h_y=200, h_x=50)
plt.savefig('kf_chi2_simhypo_xkpi.eps', bbox_inches='tight')

# %%
fl.kf_data.Draw("in_mks>>in_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_mks>>kf_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks(512,0.4,0.6)", "kf_err==0", "goff")
draw_1d_hists([('kf_vtx_mks', 'vertex fit'), 
               ('kf_mks', 'kinematic and vertex fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
              fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=200, h_x=0.05)
plt.savefig('kf_mks_simhypo_xkpi.eps',  bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
cnv = TCanvas()
fl.kf_data.Draw("kf_2stp_mks", "kf_err==0")
cnv.Draw()

# %%
# fl.kf_data.Draw("in_mks>>in_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_2stp_mks>>kf_2stp_mks(512,0.4,0.6)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_vtx_mks>>kf_vtx_mks(512,0.4,0.6)", "kf_err==0", "goff")
draw_1d_hists([('kf_vtx_mks', 'vertex fit'), 
               ('kf_2stp_mks', 'vertex fit, kinematic fit')], 
              xlabel=r'$M_{\pi^+\pi^-}$ (GeV/c$^2$)',
              ylabel='events',
              fraction=0.47,
             info_coords=(-0.2, -1.0),
            dh=0.0,
             dw=0.7,
             legend_loc='center right',
             bbox_to_anchor=(0.65, 1.1, 0.4, 0.5),
             h_y=200, h_x=0.05)

# %%
fl.kf_data.Draw("kf_vtx0[0]>>kf_vtx0_x(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx0[1]>>kf_vtx0_y(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx0[2]>>kf_vtx0_z(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[0]>>kf_vtx1_x(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[1]>>kf_vtx1_y(256, -10, 10)", "", "goff")
fl.kf_data.Draw("kf_vtx1[2]>>kf_vtx1_z(256, -10, 10)", "", "goff")
vertices_plot2([['kf_vtx0_x', 'kf_vtx1_x'], 
               ['kf_vtx0_y', 'kf_vtx1_y'],
               ['kf_vtx0_z', 'kf_vtx1_z']],
                info_coords=(0.6, 0.6))

# %%
fl.kf_data.Draw("kf_vtx_dr>>kf_vtx_dr(128, 0, 15)", "kf_err==0", "goff")
draw_1d_hist("kf_vtx_dr", 
             xlabel=r'$\Delta r_{\text{fit}}$ (cm)',
            fraction=0.47,
            info_coords=(0.3, 0.3))
# plt.savefig('kf_vtx_dr_simhypo_xkpi.eps')

# %%
cnv = TCanvas()
fl.kf_data.Draw("kf_vtx_dr", "kf_err==0")
fl.kf_data.Draw("kf_vtx_dr", "kf_err==0 && numiters>6", "same")
cnv.Draw()

# %%
fl.kf_data.Draw("kf_ks_decay_prod_angle>>kf_angle(32, 0, 3.14159)", "", "goff")
draw_1d_hist("kf_angle", xlabel=r'$\alpha$ (rad)')
plt.savefig('kf_ks_prod_angle_kskpi.eps')

# %%
fl.kf_data.Draw("kf_vtx_drho>>kf_vtx_drho(128, 0, 15)", "", "goff")
draw_1d_hist("kf_vtx_drho", xlabel=r'$\Delta\rho$ (cm)')
plt.savefig('kf_vtx_drho_kskpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_K:kf_p_vtx0_K>>pdedx_K(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_K', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_K_from_vtx0_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx0_pi:kf_p_vtx0_pi>>pdedx_vtx0_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx0_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx0_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("kf_dedx_vtx1_pi[0]:kf_p_vtx1_pi[0]>>pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
fl.kf_data.Draw("kf_dedx_vtx1_pi[1]:kf_p_vtx1_pi[1]>>+pdedx_vtx1_pi(256, 0, 0.8, 256, 0, 16000)", "kf_err==0", "goff")
draw_2d_hist('pdedx_vtx1_pi', xlabel=r'$P$ (GeV/c)', 
             ylabel=r'$dE/dx\text{ (CU)}$',
            fraction=0.47)
plt.savefig('kf_dedx_p_pi_from_vtx1_simhypo_xkpi.eps')

# %%
fl.kf_data.Draw("(kf_vtx_dr-sim_vtx_dr)>>kf_delta_dr(512, -2, 2)", "kf_err==0", "goff")
draw_1d_hist("kf_delta_dr", 
             xlabel=r'$\Delta r_{\text{fit}}-\Delta r_{\text{sim}}$ (cm)',
            fraction=0.8,
            info_coords=(0.55, 0.5))
plt.savefig('kf_sim_vs_kf_dr_1d_xkpi.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr.eps')

# %%
fl.kf_data.Draw(">>elist", "kf_err==0 && kf_chi2<100", "entryList")
draw_scatter('kf_data', 'elist', 'sim_vtx_dr', 'kf_vtx_dr', xlabel=r'$\Delta r_{\text{sim}}$ (cm)', ylabel=r'$\Delta r_{\text{kinfit}}$ (cm)')
plt.savefig('kf_sim_vs_kf_dr_chi2_100.eps')

# %%
fl.kf_data.Draw("numiters>>numiters", "kf_err==0 && numiters==6", "goff")
draw_1d_hist("numiters", xlabel=r'number of iterations')

# %%
i2 = 2384 / 20519
i3 = 11030 / 20519
i4 = 3996 / 20519
i5 = 1231 / 20519
i6 = 543 / 20519
print(i2 + i3 + i4 + i5 + i6)
# Out:
# 0.934938349822116

# %%
# fl.Close()
